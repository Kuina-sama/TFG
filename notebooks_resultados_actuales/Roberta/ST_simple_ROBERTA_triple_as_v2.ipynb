# %%
import torch
from torch.utils.data import DataLoader
from torch.optim import AdamW, SGD 


import json


from statistics import mean

# %%
import utils_generic as generic
import st_simple as st
import model_confs as confs


import train_datamaps_inprogress as train

from train import eval_func

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
model_name = 'roberta'
model_conf = confs.roberta_conf
num_labels = 2

# %% [markdown]
# # Datos ConvAI2

# %%
with open('Datasets\ConvAI2\convai2_complete.json','r') as f:
    data = json.load(f)

# %%
convai_train = data['train']
convai_val = data['validation']



convai_train_token = generic.tokenize_dataset(convai_train,['about','to','as'],model_conf) 
convai_val_token = generic.tokenize_dataset(convai_val,['about','to','as'],model_conf)

# %%
convai_train_dataset = {}
for task in ['to','as','about']:
    convai_train_dataset[task] = st.DatasetSingleTaskSimple(convai_train_token,task,eval=False)

# %%
convai_val_dataset = {}
for task in ['to','as','about']:
    convai_val_dataset[task] = st.DatasetSingleTaskSimple(convai_val_token,task,eval=False)

# %% [markdown]
# # Datos md_gender

# %%
with open('Datasets\md_gender\md_complete.json','r',encoding="utf8") as f:
    md_data = json.load(f)

# %%
md_tokenized = generic.tokenize_dataset(md_data,['about','to','as'],model_conf) 


md_dataset = {}
for task in ['to','as','about']:
    md_dataset[task] = st.DatasetSingleTaskSimple(md_tokenized,task,eval=True)

# %% [markdown]
# # Creación dataloaders

# %%
dl_train = {}
for task in ['to','as','about']:
    dl_train[task] = DataLoader(convai_train_dataset[task],batch_size=128,shuffle=True,collate_fn=st.collate_fn)

# %%
dl_val = {}
for task in ['to','as','about']:
    dl_val[task] = DataLoader(convai_val_dataset[task],batch_size=128,shuffle=True,collate_fn=st.collate_fn)

# %%
dl_eval = {}
for task in ['to','as','about']:
    dl_eval[task] = DataLoader(md_dataset[task],batch_size=128,shuffle=False,collate_fn=st.collate_fn)

# %% [markdown]
# # ABOUT

# %%
learning_rate = 1e-6
num_epochs = 100

global_metrics = {'about':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]},
                    'to':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]},
                    'as':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]}}

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
save_path=f'simple_{model_name}_about'
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['about'],optimizer,early_stop=10,dl_val=dl_val['about'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.5804654987016206 	 Validation loss: 0.4004050659931312
#   1%|          | 574/57400 [01:35<2:27:31,  6.42it/s]
# Epoch 2 	 Training loss: 0.40435758632857627 	 Validation loss: 0.35584874223854585
#   2%|▏         | 1148/57400 [03:09<2:30:21,  6.24it/s]
# Epoch 3 	 Training loss: 0.36996274908764437 	 Validation loss: 0.3367525460356373
#   3%|▎         | 1722/57400 [04:44<2:23:35,  6.46it/s]
# Epoch 4 	 Training loss: 0.35160056584699645 	 Validation loss: 0.3256099410986496
#   4%|▍         | 2296/57400 [06:19<2:23:01,  6.42it/s]
# Epoch 5 	 Training loss: 0.33483959002361896 	 Validation loss: 0.3170499592009237
#   5%|▌         | 2870/57400 [07:54<2:21:24,  6.43it/s]
# Epoch 6 	 Training loss: 0.3249048853377432 	 Validation loss: 0.31301443304045723
#   6%|▌         | 3444/57400 [09:29<2:15:00,  6.66it/s]
# Epoch 7 	 Training loss: 0.316289728682631 	 Validation loss: 0.3096270020735466
#   7%|▋         | 4018/57400 [11:04<2:17:13,  6.48it/s]
# Epoch 8 	 Training loss: 0.309668567901289 	 Validation loss: 0.3070292604171624
#   8%|▊         | 4592/57400 [12:39<2:22:45,  6.17it/s]
# Epoch 9 	 Training loss: 0.30070691942545597 	 Validation loss: 0.30071654587478963
#   9%|▉         | 5166/57400 [14:14<2:13:36,  6.52it/s]
# Epoch 10 	 Training loss: 0.2943305945614489 	 Validation loss: 0.29973437498181554
#  10%|█         | 5740/57400 [15:48<2:08:48,  6.68it/s]
# Epoch 11 	 Training loss: 0.29020313404578363 	 Validation loss: 0.29774673459893564
#  11%|█         | 6314/57400 [17:21<2:13:53,  6.36it/s]
# Epoch 12 	 Training loss: 0.2812144883262571 	 Validation loss: 0.29768446491936507
#  12%|█▏        | 6888/57400 [18:54<2:14:22,  6.26it/s]
# Epoch 13 	 Training loss: 0.27853717885989343 	 Validation loss: 0.29493133698479607
#  13%|█▎        | 7462/57400 [20:27<2:08:12,  6.49it/s]
# Epoch 14 	 Training loss: 0.27353778756661695 	 Validation loss: 0.2927596349332292
#  14%|█▍        | 8036/57400 [22:01<1:58:20,  6.95it/s]
# Epoch 15 	 Training loss: 0.2678414686787419 	 Validation loss: 0.29349290642697934
#
# 1 epoch without improvement
#  15%|█▌        | 8610/57400 [23:33<2:05:11,  6.50it/s]
# Epoch 16 	 Training loss: 0.25929452351680615 	 Validation loss: 0.29590159831410745
#
# 2 epoch without improvement
#  16%|█▌        | 9184/57400 [25:05<1:58:20,  6.79it/s]
# Epoch 17 	 Training loss: 0.2595566085536513 	 Validation loss: 0.2937686203394906
#
# 3 epoch without improvement
#  17%|█▋        | 9758/57400 [26:38<2:01:09,  6.55it/s]
# Epoch 18 	 Training loss: 0.2541424571065953 	 Validation loss: 0.2911933594841068
#  18%|█▊        | 10332/57400 [28:11<2:01:29,  6.46it/s]
# Epoch 19 	 Training loss: 0.251392109235197 	 Validation loss: 0.29289762473712533
#
# 1 epoch without improvement
#  19%|█▉        | 10906/57400 [29:43<1:57:46,  6.58it/s]
# Epoch 20 	 Training loss: 0.24549163223766698 	 Validation loss: 0.2929150318190203
#
# 2 epoch without improvement
#  20%|██        | 11480/57400 [31:15<1:57:09,  6.53it/s]
# Epoch 21 	 Training loss: 0.243119777001778 	 Validation loss: 0.2937295234809488
#
# 3 epoch without improvement
#  21%|██        | 12054/57400 [32:48<2:06:22,  5.98it/s]
# Epoch 22 	 Training loss: 0.23700392154087588 	 Validation loss: 0.29417815198332575
#
# 4 epoch without improvement
#  22%|██▏       | 12628/57400 [34:21<1:56:33,  6.40it/s]
# Epoch 23 	 Training loss: 0.23342363479245415 	 Validation loss: 0.2959659420332666
#
# 5 epoch without improvement
#  23%|██▎       | 13202/57400 [35:53<1:51:17,  6.62it/s]
# Epoch 24 	 Training loss: 0.2313977586111956 	 Validation loss: 0.2961887277789035
#
# 6 epoch without improvement
#  24%|██▍       | 13776/57400 [37:26<1:48:50,  6.68it/s]
# Epoch 25 	 Training loss: 0.2256411604764985 	 Validation loss: 0.2928174958895829
#
# 7 epoch without improvement
#  25%|██▌       | 14350/57400 [38:58<1:50:13,  6.51it/s]
# Epoch 26 	 Training loss: 0.22324457018269478 	 Validation loss: 0.30038285432225564
#
# 8 epoch without improvement
#  26%|██▌       | 14924/57400 [40:31<1:50:29,  6.41it/s]
# Epoch 27 	 Training loss: 0.2212789278308689 	 Validation loss: 0.2933428042520911
#
# 9 epoch without improvement
#  27%|██▋       | 15498/57400 [42:03<1:39:14,  7.04it/s]
# Epoch 28 	 Training loss: 0.21843155364437802 	 Validation loss: 0.29771200453830976
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 28 epochs...

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Evaluación en el conjunto el conjunto about
# recall {'female': 0.8675, 'male': 0.8619791666666666, 'average': 0.8647395833333333}
# precision {'female': 0.8675, 'male': 0.8619791666666666, 'average': 0.8647395833333333}
# f1 {'female': 0.8675, 'male': 0.8619791666666666, 'average': 0.8647395833333333}
# accuracy 0.8647959183673469
#
#
# Evaluación en el conjunto el conjunto to
# recall {'female': 0.7086614173228346, 'male': 0.7031630170316302, 'average': 0.7059122171772324}
# precision {'female': 0.6887755102040817, 'male': 0.7225, 'average': 0.7056377551020409}
# f1 {'female': 0.6985769728331177, 'male': 0.7127003699136868, 'average': 0.7056386713734022}
# accuracy 0.7058080808080808
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 0.6954177897574124, 'male': 0.696969696969697, 'average': 0.6961937433635548}
# precision {'female': 0.6825396825396826, 'male': 0.7095115681233933, 'average': 0.696025625331538}
# f1 {'female': 0.6889185580774365, 'male': 0.7031847133757961, 'average': 0.6960516357266163}
# accuracy 0.6962190352020861

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
save_path=f'simple_{model_name}_about2'

optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['about'],optimizer,early_stop=10,dl_val=dl_val['about'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.5589842526858692 	 Validation loss: 0.39547423033391016
#   1%|          | 574/57400 [01:32<2:25:28,  6.51it/s]
# Epoch 2 	 Training loss: 0.39923093797645504 	 Validation loss: 0.3535934305292065
#   2%|▏         | 1148/57400 [03:05<2:22:06,  6.60it/s]
# Epoch 3 	 Training loss: 0.3665474850801225 	 Validation loss: 0.34401196822271507
#   3%|▎         | 1722/57400 [04:38<2:21:08,  6.57it/s]
# Epoch 4 	 Training loss: 0.34800164557292484 	 Validation loss: 0.32877613225225677
#   4%|▍         | 2296/57400 [06:12<2:21:33,  6.49it/s]
# Epoch 5 	 Training loss: 0.33541171943269127 	 Validation loss: 0.31912392958746116
#   5%|▌         | 2870/57400 [07:45<2:21:27,  6.42it/s]
# Epoch 6 	 Training loss: 0.32309598558767333 	 Validation loss: 0.31398175682051704
#   6%|▌         | 3444/57400 [09:19<2:21:48,  6.34it/s]
# Epoch 7 	 Training loss: 0.3140698706387227 	 Validation loss: 0.30895654124728705
#   7%|▋         | 4018/57400 [10:52<2:18:04,  6.44it/s]
# Epoch 8 	 Training loss: 0.30821884857029863 	 Validation loss: 0.30488991232241613
#   8%|▊         | 4592/57400 [12:26<2:13:32,  6.59it/s]
# Epoch 9 	 Training loss: 0.2991120922752374 	 Validation loss: 0.3043162898492005
#   9%|▉         | 5166/57400 [13:59<2:34:07,  5.65it/s]
# Epoch 10 	 Training loss: 0.29408832268224777 	 Validation loss: 0.30381903607966537
#  10%|█         | 5740/57400 [15:32<2:09:46,  6.63it/s]
# Epoch 11 	 Training loss: 0.2878602342842348 	 Validation loss: 0.3060402769153401
#
# 1 epoch without improvement
#  11%|█         | 6314/57400 [17:05<2:23:05,  5.95it/s]
# Epoch 12 	 Training loss: 0.281384052948877 	 Validation loss: 0.29746808692560356
#  12%|█▏        | 6888/57400 [18:38<2:10:31,  6.45it/s]
# Epoch 13 	 Training loss: 0.2772896696621948 	 Validation loss: 0.2979795452901873
#
# 1 epoch without improvement
#  13%|█▎        | 7462/57400 [20:10<2:20:51,  5.91it/s]
# Epoch 14 	 Training loss: 0.2725695995192079 	 Validation loss: 0.29422686059596176
#  14%|█▍        | 8036/57400 [21:43<2:06:22,  6.51it/s]
# Epoch 15 	 Training loss: 0.2666613105749419 	 Validation loss: 0.2940757673675731
#  15%|█▌        | 8610/57400 [23:16<2:05:01,  6.50it/s]
# Epoch 16 	 Training loss: 0.2629984927977004 	 Validation loss: 0.29329739612037853
#  16%|█▌        | 9184/57400 [24:49<2:03:16,  6.52it/s]
# Epoch 17 	 Training loss: 0.25645739901875786 	 Validation loss: 0.2933928779626297
#
# 1 epoch without improvement
#  17%|█▋        | 9758/57400 [26:22<2:01:49,  6.52it/s]
# Epoch 18 	 Training loss: 0.25235883133544323 	 Validation loss: 0.2935080103955026
#
# 2 epoch without improvement
#  18%|█▊        | 10332/57400 [27:54<2:02:05,  6.42it/s]
# Epoch 19 	 Training loss: 0.24901320536066016 	 Validation loss: 0.30104536878860605
#
# 3 epoch without improvement
#  19%|█▉        | 10906/57400 [29:27<2:00:01,  6.46it/s]
# Epoch 20 	 Training loss: 0.2441369033960515 	 Validation loss: 0.29387207000942556
#
# 4 epoch without improvement
#  20%|██        | 11480/57400 [30:59<1:56:32,  6.57it/s]
# Epoch 21 	 Training loss: 0.2417745440679145 	 Validation loss: 0.2939274366629326
#
# 5 epoch without improvement
#  21%|██        | 12054/57400 [32:32<1:54:03,  6.63it/s]
# Epoch 22 	 Training loss: 0.23710533646860188 	 Validation loss: 0.29471940004219443
#
# 6 epoch without improvement
#  22%|██▏       | 12628/57400 [34:04<1:51:36,  6.69it/s]
# Epoch 23 	 Training loss: 0.23390831572461213 	 Validation loss: 0.2932287174261222
#  23%|██▎       | 13202/57400 [35:38<1:53:36,  6.48it/s]
# Epoch 24 	 Training loss: 0.2307031398528752 	 Validation loss: 0.29499699049076794
#
# 1 epoch without improvement
#  24%|██▍       | 13776/57400 [37:11<1:55:36,  6.29it/s]
# Epoch 25 	 Training loss: 0.22596669468366726 	 Validation loss: 0.2959249686386626
#
# 2 epoch without improvement
#  25%|██▌       | 14350/57400 [38:44<1:50:11,  6.51it/s]
# Epoch 26 	 Training loss: 0.22572307671559813 	 Validation loss: 0.29839643280384903
#
# 3 epoch without improvement
#  26%|██▌       | 14924/57400 [40:17<1:48:32,  6.52it/s]
# Epoch 27 	 Training loss: 0.21856376558594173 	 Validation loss: 0.30264748557139254
#
# 4 epoch without improvement
#  27%|██▋       | 15498/57400 [41:50<1:47:53,  6.47it/s]
# Epoch 28 	 Training loss: 0.21662296178241225 	 Validation loss: 0.29994539234597806
#
# 5 epoch without improvement
#  28%|██▊       | 16072/57400 [43:23<1:48:21,  6.36it/s]
# Epoch 29 	 Training loss: 0.21216763328851723 	 Validation loss: 0.3019513295868696
#
# 6 epoch without improvement
#  29%|██▉       | 16646/57400 [44:56<1:48:11,  6.28it/s]
# Epoch 30 	 Training loss: 0.21035530483058104 	 Validation loss: 0.3015838091151189
#
# 7 epoch without improvement
#  30%|███       | 17220/57400 [46:28<1:40:56,  6.63it/s]
# Epoch 31 	 Training loss: 0.20667916040491144 	 Validation loss: 0.30595337384838167
#
# 8 epoch without improvement
#  31%|███       | 17794/57400 [48:02<1:54:30,  5.76it/s]
# Epoch 32 	 Training loss: 0.20403550619759211 	 Validation loss: 0.30489490446397816
#
# 9 epoch without improvement
#  32%|███▏      | 18368/57400 [49:34<1:43:01,  6.31it/s]
# Epoch 33 	 Training loss: 0.20166590972073403 	 Validation loss: 0.3043745753623672
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 33 epochs...

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Evaluación en el conjunto el conjunto about
# recall {'female': 0.8625, 'male': 0.8697916666666666, 'average': 0.8661458333333334}
# precision {'female': 0.8734177215189873, 'male': 0.8586118251928021, 'average': 0.8660147733558947}
# f1 {'female': 0.8679245283018868, 'male': 0.8641655886157826, 'average': 0.8660450584588347}
# accuracy 0.8660714285714286
#
#
# Evaluación en el conjunto el conjunto to
# recall {'female': 0.6876640419947506, 'male': 0.7128953771289538, 'average': 0.7002797095618523}
# precision {'female': 0.6894736842105263, 'male': 0.7111650485436893, 'average': 0.7003193663771079}
# f1 {'female': 0.6885676741130091, 'male': 0.7120291616038881, 'average': 0.7002984178584486}
# accuracy 0.7007575757575758
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 0.6846361185983828, 'male': 0.7070707070707071, 'average': 0.6958534128345449}
# precision {'female': 0.6864864864864865, 'male': 0.7052896725440806, 'average': 0.6958880795152835}
# f1 {'female': 0.6855600539811066, 'male': 0.7061790668348046, 'average': 0.6958695604079557}
# accuracy 0.6962190352020861

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
save_path=f'simple_{model_name}_about3'

optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['about'],optimizer,early_stop=10,dl_val=dl_val['about'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.5512892680197228 	 Validation loss: 0.3996785737700381
#   1%|          | 574/57400 [01:33<2:19:13,  6.80it/s]
# Epoch 2 	 Training loss: 0.40574834010326905 	 Validation loss: 0.35835374462402475
#   2%|▏         | 1148/57400 [03:06<2:35:52,  6.01it/s]
# Epoch 3 	 Training loss: 0.37038607223004827 	 Validation loss: 0.3375996242640382
#   3%|▎         | 1722/57400 [04:39<2:24:12,  6.44it/s]
# Epoch 4 	 Training loss: 0.35061270346417245 	 Validation loss: 0.3293972646785995
#   4%|▍         | 2296/57400 [06:12<2:16:13,  6.74it/s]
# Epoch 5 	 Training loss: 0.3399232034587694 	 Validation loss: 0.31893102218539027
#   5%|▌         | 2870/57400 [07:49<2:27:11,  6.17it/s]
# Epoch 6 	 Training loss: 0.32738259203654135 	 Validation loss: 0.3125456649873216
#   6%|▌         | 3444/57400 [09:25<2:20:04,  6.42it/s]
# Epoch 7 	 Training loss: 0.3169557468037572 	 Validation loss: 0.3078095935663934
#   7%|▋         | 4018/57400 [11:01<2:23:46,  6.19it/s]
# Epoch 8 	 Training loss: 0.3090743982469994 	 Validation loss: 0.30482311471033907
#   8%|▊         | 4592/57400 [12:37<2:07:08,  6.92it/s]
# Epoch 9 	 Training loss: 0.30259535012552546 	 Validation loss: 0.3018010867349172
#   9%|▉         | 5166/57400 [14:13<2:09:46,  6.71it/s]
# Epoch 10 	 Training loss: 0.29615667641474397 	 Validation loss: 0.30024702240855006
#  10%|█         | 5740/57400 [15:49<2:16:19,  6.32it/s]
# Epoch 11 	 Training loss: 0.28955718267462394 	 Validation loss: 0.29960053477246884
#  11%|█         | 6314/57400 [17:26<2:14:14,  6.34it/s]
# Epoch 12 	 Training loss: 0.28246386092195114 	 Validation loss: 0.2988205094963817
#  12%|█▏        | 6888/57400 [19:02<2:06:29,  6.66it/s]
# Epoch 13 	 Training loss: 0.2792983096910686 	 Validation loss: 0.2989005787392794
#
# 1 epoch without improvement
#  13%|█▎        | 7462/57400 [20:37<2:08:45,  6.46it/s]
# Epoch 14 	 Training loss: 0.27355160141032747 	 Validation loss: 0.2985162181874453
#  14%|█▍        | 8036/57400 [22:13<2:18:50,  5.93it/s]
# Epoch 15 	 Training loss: 0.27027487186293153 	 Validation loss: 0.29512978105221765
#  15%|█▌        | 8610/57400 [23:48<2:02:49,  6.62it/s]
# Epoch 16 	 Training loss: 0.26317055165144626 	 Validation loss: 0.29574828708575945
#
# 1 epoch without improvement
#  16%|█▌        | 9184/57400 [25:20<2:06:29,  6.35it/s]
# Epoch 17 	 Training loss: 0.2603473647234747 	 Validation loss: 0.2936959925849559
#  17%|█▋        | 9758/57400 [26:54<1:59:12,  6.66it/s]
# Epoch 18 	 Training loss: 0.256351758093161 	 Validation loss: 0.29399576581130593
#
# 1 epoch without improvement
#  18%|█▊        | 10332/57400 [28:27<2:02:40,  6.39it/s]
# Epoch 19 	 Training loss: 0.2505319664702598 	 Validation loss: 0.2943045572709229
#
# 2 epoch without improvement
#  19%|█▉        | 10906/57400 [30:00<1:59:16,  6.50it/s]
# Epoch 20 	 Training loss: 0.24779837316336947 	 Validation loss: 0.2953632956339141
#
# 3 epoch without improvement
#  20%|██        | 11480/57400 [31:32<2:05:35,  6.09it/s]
# Epoch 21 	 Training loss: 0.24245732842266352 	 Validation loss: 0.29712775299104593
#
# 4 epoch without improvement
#  21%|██        | 12054/57400 [33:05<2:00:11,  6.29it/s]
# Epoch 22 	 Training loss: 0.23768617368533637 	 Validation loss: 0.2993453056630442
#
# 5 epoch without improvement
#  22%|██▏       | 12628/57400 [34:37<1:52:57,  6.61it/s]
# Epoch 23 	 Training loss: 0.23494704551865 	 Validation loss: 0.2980716902825792
#
# 6 epoch without improvement
#  23%|██▎       | 13202/57400 [36:10<1:59:53,  6.14it/s]
# Epoch 24 	 Training loss: 0.23285621874527648 	 Validation loss: 0.2996772810564203
#
# 7 epoch without improvement
#  24%|██▍       | 13776/57400 [37:42<1:50:59,  6.55it/s]
# Epoch 25 	 Training loss: 0.2289255539065662 	 Validation loss: 0.29732139332819796
#
# 8 epoch without improvement
#  25%|██▌       | 14350/57400 [39:15<1:48:45,  6.60it/s]
# Epoch 26 	 Training loss: 0.22443714048648544 	 Validation loss: 0.2993221525418556
#
# 9 epoch without improvement
#  26%|██▌       | 14924/57400 [40:47<1:49:57,  6.44it/s]
# Epoch 27 	 Training loss: 0.2221885044062802 	 Validation loss: 0.2995410526202897
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 27 epochs...

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Evaluación en el conjunto el conjunto about
# recall {'female': 0.8475, 'male': 0.8619791666666666, 'average': 0.8547395833333333}
# precision {'female': 0.8647959183673469, 'male': 0.8443877551020408, 'average': 0.8545918367346939}
# f1 {'female': 0.8560606060606061, 'male': 0.8530927835051546, 'average': 0.8545766947828803}
# accuracy 0.8545918367346939
#
#
# Evaluación en el conjunto el conjunto to
# recall {'female': 0.6902887139107612, 'male': 0.7201946472019465, 'average': 0.7052416805563538}
# precision {'female': 0.6957671957671958, 'male': 0.714975845410628, 'average': 0.705371520588912}
# f1 {'female': 0.6930171277997366, 'male': 0.7175757575757575, 'average': 0.705296442687747}
# accuracy 0.7058080808080808
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 0.6873315363881402, 'male': 0.7196969696969697, 'average': 0.7035142530425549}
# precision {'female': 0.6967213114754098, 'male': 0.7107231920199502, 'average': 0.70372225174768}
# f1 {'female': 0.6919945725915875, 'male': 0.7151819322459223, 'average': 0.7035882524187549}
# accuracy 0.7040417209908736

# %% [markdown]
# Resultados finales

# %%
print('f1 medio de los 3 modelos: \n')
for task in ['about','to','as']:
    print('\n',task)
    print('Resultado global F1:',mean(global_metrics[task]['f1']['average']))
    print(f'F1 etiqueta male:',mean(global_metrics[task]['f1']['male']))
    print('F1 etiqueta female: ',mean(global_metrics[task]['f1']['female']))
# Out:
# f1 medio de los 3 modelos:
#
#
#  about
# Resultado global F1: 0.8617871121916828
# F1 etiqueta male: 0.8597458462625346
# F1 etiqueta female:  0.863828378120831
#
#  to
# Resultado global F1: 0.703744510639866
# F1 etiqueta male: 0.7141017630311108
# F1 etiqueta female:  0.6933872582486211
#
#  as
# Resultado global F1: 0.6985031495177756
# F1 etiqueta male: 0.7081819041521743
# F1 etiqueta female:  0.6888243948833769

# %%
for metric in ['f1','recall','precision']:
    print(f'{metric} medio de los 3 modelos: \n')
    for task in ['about','to','as']:
        print(task.upper())
        print(f'Resultado global {metric}:',mean(global_metrics[task]['f1']['average']))
        print(f'{metric} etiqueta male:',mean(global_metrics[task]['f1']['male']))
        print(f'{metric} etiqueta female: ',mean(global_metrics[task]['f1']['female']))
        print('\n')

print(f'Accuracy medio de los 3 modelos: \n')
for task in ['about','to','as']:
    print('\n',task.upper())
    print('Resultado global accuracy:',mean(global_metrics[task]['acc']))
# Out:
# f1 medio de los 3 modelos:
#
# ABOUT
# Resultado global f1: 0.8617871121916828
# f1 etiqueta male: 0.8597458462625346
# f1 etiqueta female:  0.863828378120831
#
#
# TO
# Resultado global f1: 0.703744510639866
# f1 etiqueta male: 0.7141017630311108
# f1 etiqueta female:  0.6933872582486211
#
#
# AS
# Resultado global f1: 0.6985031495177756
# f1 etiqueta male: 0.7081819041521743
# f1 etiqueta female:  0.6888243948833769
#
#
# recall medio de los 3 modelos:
#
# ABOUT
# Resultado global recall: 0.8617871121916828
# recall etiqueta male: 0.8597458462625346
# recall etiqueta female:  0.863828378120831
#
#
# TO
# Resultado global recall: 0.703744510639866
# recall etiqueta male: 0.7141017630311108
# recall etiqueta female:  0.6933872582486211
#
#
# AS
# Resultado global recall: 0.6985031495177756
# recall etiqueta male: 0.7081819041521743
# recall etiqueta female:  0.6888243948833769
#
#
# precision medio de los 3 modelos:
#
# ABOUT
# Resultado global precision: 0.8617871121916828
# precision etiqueta male: 0.8597458462625346
# precision etiqueta female:  0.863828378120831
#
#
# TO
# Resultado global precision: 0.703744510639866
# precision etiqueta male: 0.7141017630311108
# precision etiqueta female:  0.6933872582486211
#
#
# AS
# Resultado global precision: 0.6985031495177756
# precision etiqueta male: 0.7081819041521743
# precision etiqueta female:  0.6888243948833769
#
#
# Accuracy medio de los 3 modelos:
#
#
#  ABOUT
# Resultado global accuracy: 0.8618197278911565
#
#  TO
# Resultado global accuracy: 0.7041245791245792
#
#  AS
# Resultado global accuracy: 0.6988265971316819

# %% [markdown]
# # TO

# %%
learning_rate = 1e-6
num_epochs = 100

global_metrics = {'about':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]},
                    'to':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]},
                    'as':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]}}

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
save_path=f'simple_{model_name}_to'
optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['to'],optimizer,early_stop=10,dl_val=dl_val['to'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.6933746410579216 	 Validation loss: 0.6925331788547968
#   1%|          | 574/57400 [01:33<2:31:53,  6.24it/s]
# Epoch 2 	 Training loss: 0.6933779779834615 	 Validation loss: 0.6931548744945203
#
# 1 epoch without improvement
#   2%|▏         | 1148/57400 [03:06<2:27:58,  6.34it/s]
# Epoch 3 	 Training loss: 0.6933076017201986 	 Validation loss: 0.6920590451208212
#   3%|▎         | 1722/57400 [04:39<2:19:07,  6.67it/s]
# Epoch 4 	 Training loss: 0.6934228989097715 	 Validation loss: 0.693137321431758
#
# 1 epoch without improvement
#   4%|▍         | 2296/57400 [06:13<2:23:55,  6.38it/s]
# Epoch 5 	 Training loss: 0.6933921704308912 	 Validation loss: 0.6927166439719119
#
# 2 epoch without improvement
#   5%|▌         | 2870/57400 [07:45<2:18:52,  6.54it/s]
# Epoch 6 	 Training loss: 0.6931863210134805 	 Validation loss: 0.6922370306516098
#
# 3 epoch without improvement
#   6%|▌         | 3444/57400 [09:18<2:22:03,  6.33it/s]
# Epoch 7 	 Training loss: 0.6932355084485708 	 Validation loss: 0.6926482087474758
#
# 4 epoch without improvement
#   7%|▋         | 4018/57400 [10:51<2:38:13,  5.62it/s]
# Epoch 8 	 Training loss: 0.6931417106751365 	 Validation loss: 0.6930265487250635
#
# 5 epoch without improvement
#   8%|▊         | 4592/57400 [12:24<2:11:19,  6.70it/s]
# Epoch 9 	 Training loss: 0.6930580380070915 	 Validation loss: 0.6926293443825285
#
# 6 epoch without improvement
#   9%|▉         | 5166/57400 [13:57<2:12:18,  6.58it/s]
# Epoch 10 	 Training loss: 0.6930598855433979 	 Validation loss: 0.6921699178420891
#
# 7 epoch without improvement
#  10%|█         | 5740/57400 [15:31<2:21:01,  6.11it/s]
# Epoch 11 	 Training loss: 0.6929595181750919 	 Validation loss: 0.6931849465531817
#
# 8 epoch without improvement
#  11%|█         | 6314/57400 [17:04<2:10:58,  6.50it/s]
# Epoch 12 	 Training loss: 0.6931137047993596 	 Validation loss: 0.6927237086376902
#
# 9 epoch without improvement
#  12%|█▏        | 6888/57400 [18:36<2:15:41,  6.20it/s]
# Epoch 13 	 Training loss: 0.6927170846935764 	 Validation loss: 0.6932010792069516
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 13 epochs...

# %%
model = st.SingleTaskSimple(model_conf).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Evaluación en el conjunto el conjunto about
# c:\Users\FarinhOso\anaconda3\envs\tfg\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# recall {'female': 1.0, 'male': 0.0, 'average': 0.5}
# precision {'female': 0.5102040816326531, 'male': 0.0, 'average': 0.25510204081632654}
# f1 {'female': 0.6756756756756758, 'male': 0.0, 'average': 0.3378378378378379}
# accuracy 0.5102040816326531
#
#
# Evaluación en el conjunto el conjunto to
# c:\Users\FarinhOso\anaconda3\envs\tfg\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# recall {'female': 1.0, 'male': 0.0, 'average': 0.5}
# precision {'female': 0.4810606060606061, 'male': 0.0, 'average': 0.24053030303030304}
# f1 {'female': 0.6496163682864451, 'male': 0.0, 'average': 0.32480818414322254}
# accuracy 0.4810606060606061
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 1.0, 'male': 0.0, 'average': 0.5}
# precision {'female': 0.48370273794002605, 'male': 0.0, 'average': 0.24185136897001303}
# f1 {'female': 0.6520210896309314, 'male': 0.0, 'average': 0.3260105448154657}
# accuracy 0.48370273794002605
# c:\Users\FarinhOso\anaconda3\envs\tfg\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
save_path=f'simple_{model_name}_to2'

optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['to'],optimizer,early_stop=10,dl_val=dl_val['to'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.697236557040065 	 Validation loss: 0.6936433466814332
#   1%|          | 574/57400 [01:33<2:27:27,  6.42it/s]
# Epoch 2 	 Training loss: 0.6958012038822373 	 Validation loss: 0.6923378776695769
#   2%|▏         | 1148/57400 [03:06<2:12:58,  7.05it/s]
# Epoch 3 	 Training loss: 0.6955102935485308 	 Validation loss: 0.6932120282771224
#
# 1 epoch without improvement
#   3%|▎         | 1722/57400 [04:39<2:20:57,  6.58it/s]
# Epoch 4 	 Training loss: 0.6949639554015435 	 Validation loss: 0.6926483491719779
#
# 2 epoch without improvement
#   4%|▍         | 2296/57400 [06:12<2:21:41,  6.48it/s]
# Epoch 5 	 Training loss: 0.6950144008684657 	 Validation loss: 0.6926106497392817
#
# 3 epoch without improvement
#   5%|▌         | 2870/57400 [07:44<2:15:52,  6.69it/s]
# Epoch 6 	 Training loss: 0.6951885351112911 	 Validation loss: 0.6925529170844514
#
# 4 epoch without improvement
#   6%|▌         | 3444/57400 [09:17<2:20:39,  6.39it/s]
# Epoch 7 	 Training loss: 0.6949764105916438 	 Validation loss: 0.6920490891246472
#   7%|▋         | 4018/57400 [10:51<2:18:29,  6.42it/s]
# Epoch 8 	 Training loss: 0.6946890467343014 	 Validation loss: 0.6947585223084789
#
# 1 epoch without improvement
#   8%|▊         | 4592/57400 [12:24<2:14:07,  6.56it/s]
# Epoch 9 	 Training loss: 0.6948226698599625 	 Validation loss: 0.6928192134630882
#
# 2 epoch without improvement
#   9%|▉         | 5166/57400 [13:56<2:16:50,  6.36it/s]
# Epoch 10 	 Training loss: 0.6945085601316512 	 Validation loss: 0.6934650328199742
#
# 3 epoch without improvement
#  10%|█         | 5740/57400 [15:29<2:08:35,  6.70it/s]
# Epoch 11 	 Training loss: 0.694385930116999 	 Validation loss: 0.6921922796863621
#
# 4 epoch without improvement
#  11%|█         | 6314/57400 [17:02<2:07:07,  6.70it/s]
# Epoch 12 	 Training loss: 0.6944662065663819 	 Validation loss: 0.693542644128961
#
# 5 epoch without improvement
#  12%|█▏        | 6888/57400 [18:35<2:09:34,  6.50it/s]
# Epoch 13 	 Training loss: 0.6936561639715986 	 Validation loss: 0.6921374828128491
#
# 6 epoch without improvement
#  13%|█▎        | 7462/57400 [20:08<2:05:42,  6.62it/s]
# Epoch 14 	 Training loss: 0.6939660616037322 	 Validation loss: 0.6918700690996848
#  14%|█▍        | 8036/57400 [21:42<2:06:29,  6.50it/s]
# Epoch 15 	 Training loss: 0.6939024261688936 	 Validation loss: 0.6931592195720996
#
# 1 epoch without improvement
#  15%|█▌        | 8610/57400 [23:14<2:04:31,  6.53it/s]
# Epoch 16 	 Training loss: 0.6939109709204697 	 Validation loss: 0.693020294278355
#
# 2 epoch without improvement
#  16%|█▌        | 9184/57400 [24:48<2:04:46,  6.44it/s]
# Epoch 17 	 Training loss: 0.6934106015577549 	 Validation loss: 0.692389190196991
#
# 3 epoch without improvement
#  17%|█▋        | 9758/57400 [26:21<2:02:33,  6.48it/s]
# Epoch 18 	 Training loss: 0.6934065005712808 	 Validation loss: 0.6942020270784023
#
# 4 epoch without improvement
#  18%|█▊        | 10332/57400 [27:53<2:00:37,  6.50it/s]
# Epoch 19 	 Training loss: 0.6935939168888517 	 Validation loss: 0.6929568537211014
#
# 5 epoch without improvement
#  19%|█▉        | 10906/57400 [29:26<1:55:56,  6.68it/s]
# Epoch 20 	 Training loss: 0.69278157650386 	 Validation loss: 0.6942181284144774
#
# 6 epoch without improvement
#  20%|██        | 11480/57400 [30:59<1:57:23,  6.52it/s]
# Epoch 21 	 Training loss: 0.6931223959665265 	 Validation loss: 0.6938952005515664
#
# 7 epoch without improvement
#  21%|██        | 12054/57400 [32:31<1:53:34,  6.65it/s]
# Epoch 22 	 Training loss: 0.6933071296597192 	 Validation loss: 0.6936679492562504
#
# 8 epoch without improvement
#  22%|██▏       | 12628/57400 [34:04<1:52:58,  6.60it/s]
# Epoch 23 	 Training loss: 0.6931452098000755 	 Validation loss: 0.6928654040320444
#
# 9 epoch without improvement
#  23%|██▎       | 13202/57400 [35:38<1:49:47,  6.71it/s]
# Epoch 24 	 Training loss: 0.6932171732706476 	 Validation loss: 0.6937722432411323
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 24 epochs...

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Evaluación en el conjunto el conjunto about
# recall {'female': 0.9175, 'male': 0.14583333333333334, 'average': 0.5316666666666666}
# precision {'female': 0.5280575539568345, 'male': 0.6292134831460674, 'average': 0.5786355185514509}
# f1 {'female': 0.6703196347031963, 'male': 0.23678646934460887, 'average': 0.4535530520239026}
# accuracy 0.5395408163265306
#
#
# Evaluación en el conjunto el conjunto to
# recall {'female': 0.94750656167979, 'male': 0.17274939172749393, 'average': 0.560127976703642}
# precision {'female': 0.514978601997147, 'male': 0.7802197802197802, 'average': 0.6475991911084635}
# f1 {'female': 0.66728280961183, 'male': 0.2828685258964143, 'average': 0.47507566775412213}
# accuracy 0.5454545454545454
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 0.9272237196765498, 'male': 0.16414141414141414, 'average': 0.545682566908982}
# precision {'female': 0.5096296296296297, 'male': 0.7065217391304348, 'average': 0.6080756843800322}
# f1 {'female': 0.6577437858508604, 'male': 0.26639344262295084, 'average': 0.4620686142369056}
# accuracy 0.5332464146023468

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
save_path=f'simple_{model_name}_to3'

optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['to'],optimizer,early_stop=10,dl_val=dl_val['to'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.7032101987130966 	 Validation loss: 0.6930475628982156
#   1%|          | 574/57400 [01:33<2:25:34,  6.51it/s]
# Epoch 2 	 Training loss: 0.6981480373945801 	 Validation loss: 0.6923302664595136
#   2%|▏         | 1148/57400 [03:07<2:25:26,  6.45it/s]
# Epoch 3 	 Training loss: 0.6959659122839207 	 Validation loss: 0.6927825242786084
#
# 1 epoch without improvement
#   3%|▎         | 1722/57400 [04:40<2:19:53,  6.63it/s]
# Epoch 4 	 Training loss: 0.6952309740337346 	 Validation loss: 0.6926781696788336
#
# 2 epoch without improvement
#   4%|▍         | 2296/57400 [06:13<2:24:05,  6.37it/s]
# Epoch 5 	 Training loss: 0.6947926080393043 	 Validation loss: 0.6928335822234719
#
# 3 epoch without improvement
#   5%|▌         | 2870/57400 [07:46<2:20:13,  6.48it/s]
# Epoch 6 	 Training loss: 0.6946511970579832 	 Validation loss: 0.6920065324185258
#   6%|▌         | 3444/57400 [09:20<2:20:50,  6.38it/s]
# Epoch 7 	 Training loss: 0.6946543086488903 	 Validation loss: 0.6924943641080694
#
# 1 epoch without improvement
#   7%|▋         | 4018/57400 [10:53<2:17:50,  6.45it/s]
# Epoch 8 	 Training loss: 0.6945979348043116 	 Validation loss: 0.6922265937772848
#
# 2 epoch without improvement
#   8%|▊         | 4592/57400 [12:27<2:18:26,  6.36it/s]
# Epoch 9 	 Training loss: 0.693910545899893 	 Validation loss: 0.6941715751664114
#
# 3 epoch without improvement
#   9%|▉         | 5166/57400 [14:00<2:10:12,  6.69it/s]
# Epoch 10 	 Training loss: 0.6937758891424651 	 Validation loss: 0.6917329006275889
#  10%|█         | 5740/57400 [15:34<2:22:44,  6.03it/s]
# Epoch 11 	 Training loss: 0.6938604308545382 	 Validation loss: 0.6921665991766978
#
# 1 epoch without improvement
#  11%|█         | 6314/57400 [17:07<2:13:36,  6.37it/s]
# Epoch 12 	 Training loss: 0.6938424696074961 	 Validation loss: 0.6922452096211709
#
# 2 epoch without improvement
#  12%|█▏        | 6888/57400 [18:42<2:02:18,  6.88it/s]
# Epoch 13 	 Training loss: 0.6931745896979076 	 Validation loss: 0.6910741268578222
#  13%|█▎        | 7462/57400 [20:15<2:12:00,  6.30it/s]
# Epoch 14 	 Training loss: 0.6936004569929236 	 Validation loss: 0.6939791046966941
#
# 1 epoch without improvement
#  14%|█▍        | 8036/57400 [21:48<2:05:48,  6.54it/s]
# Epoch 15 	 Training loss: 0.6931939624535497 	 Validation loss: 0.6916887376268032
#
# 2 epoch without improvement
#  15%|█▌        | 8610/57400 [23:20<1:53:06,  7.19it/s]
# Epoch 16 	 Training loss: 0.692870663537381 	 Validation loss: 0.6917128209340371
#
# 3 epoch without improvement
#  16%|█▌        | 9184/57400 [24:54<2:05:59,  6.38it/s]
# Epoch 17 	 Training loss: 0.6929314895581701 	 Validation loss: 0.6909561116816634
#  17%|█▋        | 9758/57400 [26:27<2:03:29,  6.43it/s]
# Epoch 18 	 Training loss: 0.6932128803862927 	 Validation loss: 0.6916334184549623
#
# 1 epoch without improvement
#  18%|█▊        | 10332/57400 [28:00<1:57:16,  6.69it/s]
# Epoch 19 	 Training loss: 0.6934690371623022 	 Validation loss: 0.694272662623454
#
# 2 epoch without improvement
#  19%|█▉        | 10906/57400 [29:32<1:57:58,  6.57it/s]
# Epoch 20 	 Training loss: 0.6929446846142878 	 Validation loss: 0.6926958581148568
#
# 3 epoch without improvement
#  20%|██        | 11480/57400 [31:05<1:56:44,  6.56it/s]
# Epoch 21 	 Training loss: 0.6931821697680377 	 Validation loss: 0.6939944109674228
#
# 4 epoch without improvement
#  21%|██        | 12054/57400 [32:38<1:53:52,  6.64it/s]
# Epoch 22 	 Training loss: 0.6929307992242355 	 Validation loss: 0.6920811958232168
#
# 5 epoch without improvement
#  22%|██▏       | 12628/57400 [34:10<1:56:41,  6.40it/s]
# Epoch 23 	 Training loss: 0.6927126106069479 	 Validation loss: 0.6919405329025398
#
# 6 epoch without improvement
#  23%|██▎       | 13202/57400 [35:43<1:54:45,  6.42it/s]
# Epoch 24 	 Training loss: 0.692773762584148 	 Validation loss: 0.6932870513301784
#
# 7 epoch without improvement
#  24%|██▍       | 13776/57400 [37:16<1:55:01,  6.32it/s]
# Epoch 25 	 Training loss: 0.6927918749196189 	 Validation loss: 0.692947455381943
#
# 8 epoch without improvement
#  25%|██▌       | 14350/57400 [38:49<1:49:30,  6.55it/s]
# Epoch 26 	 Training loss: 0.6922704523448745 	 Validation loss: 0.6936733934838893
#
# 9 epoch without improvement
#  26%|██▌       | 14924/57400 [40:22<1:54:29,  6.18it/s]
# Epoch 27 	 Training loss: 0.6924789691220593 	 Validation loss: 0.6916284450029923
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 27 epochs...

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Evaluación en el conjunto el conjunto about
# recall {'female': 0.965, 'male': 0.11458333333333333, 'average': 0.5397916666666667}
# precision {'female': 0.5316804407713499, 'male': 0.7586206896551724, 'average': 0.6451505652132612}
# f1 {'female': 0.6856127886323269, 'male': 0.19909502262443438, 'average': 0.4423539056283806}
# accuracy 0.548469387755102
#
#
# Evaluación en el conjunto el conjunto to
# recall {'female': 0.952755905511811, 'male': 0.145985401459854, 'average': 0.5493706534858325}
# precision {'female': 0.5084033613445378, 'male': 0.7692307692307693, 'average': 0.6388170652876535}
# f1 {'female': 0.6630136986301369, 'male': 0.24539877300613497, 'average': 0.45420623581813596}
# accuracy 0.5340909090909091
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 0.9568733153638814, 'male': 0.14393939393939395, 'average': 0.5504063546516377}
# precision {'female': 0.5115273775216138, 'male': 0.7808219178082192, 'average': 0.6461746476649165}
# f1 {'female': 0.6666666666666667, 'male': 0.24307036247334757, 'average': 0.45486851457000715}
# accuracy 0.5371577574967406

# %% [markdown]
# Resultados finales

# %%
for metric in ['f1','recall','precision']:
    print(f'{metric} medio de los 3 modelos: \n')
    for task in ['about','to','as']:
        print(task.upper())
        print(f'Resultado global {metric}:',mean(global_metrics[task]['f1']['average']))
        print(f'{metric} etiqueta male:',mean(global_metrics[task]['f1']['male']))
        print(f'{metric} etiqueta female: ',mean(global_metrics[task]['f1']['female']))
        print('\n')

print(f'Accuracy medio de los 3 modelos: \n')
for task in ['about','to','as']:
    print('\n',task.upper())
    print('Resultado global accuracy:',mean(global_metrics[task]['acc']))
# Out:
# f1 medio de los 3 modelos:
#
# ABOUT
# Resultado global f1: 0.4112482651633737
# f1 etiqueta male: 0.14529383065634774
# f1 etiqueta female:  0.6772026996703997
#
#
# TO
# Resultado global f1: 0.41803002923849353
# f1 etiqueta male: 0.1760890996341831
# f1 etiqueta female:  0.659970958842804
#
#
# AS
# Resultado global f1: 0.4143158912074595
# f1 etiqueta male: 0.1698212683654328
# f1 etiqueta female:  0.6588105140494862
#
#
# recall medio de los 3 modelos:
#
# ABOUT
# Resultado global recall: 0.4112482651633737
# recall etiqueta male: 0.14529383065634774
# recall etiqueta female:  0.6772026996703997
#
#
# TO
# Resultado global recall: 0.41803002923849353
# recall etiqueta male: 0.1760890996341831
# recall etiqueta female:  0.659970958842804
#
#
# AS
# Resultado global recall: 0.4143158912074595
# recall etiqueta male: 0.1698212683654328
# recall etiqueta female:  0.6588105140494862
#
#
# precision medio de los 3 modelos:
#
# ABOUT
# Resultado global precision: 0.4112482651633737
# precision etiqueta male: 0.14529383065634774
# precision etiqueta female:  0.6772026996703997
#
#
# TO
# Resultado global precision: 0.41803002923849353
# precision etiqueta male: 0.1760890996341831
# precision etiqueta female:  0.659970958842804
#
#
# AS
# Resultado global precision: 0.4143158912074595
# precision etiqueta male: 0.1698212683654328
# precision etiqueta female:  0.6588105140494862
#
#
# Accuracy medio de los 3 modelos:
#
#
#  ABOUT
# Resultado global accuracy: 0.5327380952380952
#
#  TO
# Resultado global accuracy: 0.5202020202020202
#
#  AS
# Resultado global accuracy: 0.5180356366797044

# %% [markdown]
# # AS

# %%
learning_rate = 1e-6
num_epochs = 100

global_metrics = {'about':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]},
                    'to':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]},
                    'as':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]}}

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
save_path=f'simple_{model_name}_as'

optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['to'],optimizer,early_stop=10,dl_val=dl_val['to'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.6976082341596225 	 Validation loss: 0.6925169795246447
#   1%|          | 574/57400 [01:33<2:22:31,  6.65it/s]
# Epoch 2 	 Training loss: 0.696596090075031 	 Validation loss: 0.6927300267300364
#
# 1 epoch without improvement
#   2%|▏         | 1148/57400 [03:06<2:28:50,  6.30it/s]
# Epoch 3 	 Training loss: 0.696769648001169 	 Validation loss: 0.6915198231147508
#   3%|▎         | 1722/57400 [04:40<2:21:01,  6.58it/s]
# Epoch 4 	 Training loss: 0.6963113496527854 	 Validation loss: 0.6920097399566133
#
# 1 epoch without improvement
#   4%|▍         | 2296/57400 [06:14<2:23:01,  6.42it/s]
# Epoch 5 	 Training loss: 0.695937630399179 	 Validation loss: 0.6940161181708514
#
# 2 epoch without improvement
#   5%|▌         | 2870/57400 [07:46<2:23:10,  6.35it/s]
# Epoch 6 	 Training loss: 0.6958215088171411 	 Validation loss: 0.6933791920290155
#
# 3 epoch without improvement
#   6%|▌         | 3444/57400 [09:20<2:02:50,  7.32it/s]
# Epoch 7 	 Training loss: 0.6951883156955865 	 Validation loss: 0.6924764756428994
#
# 4 epoch without improvement
#   7%|▋         | 4018/57400 [10:53<2:13:18,  6.67it/s]
# Epoch 8 	 Training loss: 0.6956098736993942 	 Validation loss: 0.6932195263393854
#
# 5 epoch without improvement
#   8%|▊         | 4592/57400 [12:25<2:39:18,  5.52it/s]
# Epoch 9 	 Training loss: 0.6949029558627032 	 Validation loss: 0.6921482308436249
#
# 6 epoch without improvement
#   9%|▉         | 5166/57400 [13:58<2:10:40,  6.66it/s]
# Epoch 10 	 Training loss: 0.6956056873557459 	 Validation loss: 0.6940709685875197
#
# 7 epoch without improvement
#  10%|█         | 5740/57400 [15:30<2:19:42,  6.16it/s]
# Epoch 11 	 Training loss: 0.6947286492440758 	 Validation loss: 0.6920684919518939
#
# 8 epoch without improvement
#  11%|█         | 6314/57400 [17:03<2:13:14,  6.39it/s]
# Epoch 12 	 Training loss: 0.6949755198448793 	 Validation loss: 0.6928977915796183
#
# 9 epoch without improvement
#  12%|█▏        | 6888/57400 [18:36<2:07:59,  6.58it/s]
# Epoch 13 	 Training loss: 0.694022329219127 	 Validation loss: 0.6915577084331189
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 13 epochs...

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Evaluación en el conjunto el conjunto about
# c:\Users\FarinhOso\anaconda3\envs\tfg\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# recall {'female': 1.0, 'male': 0.0, 'average': 0.5}
# precision {'female': 0.5102040816326531, 'male': 0.0, 'average': 0.25510204081632654}
# f1 {'female': 0.6756756756756758, 'male': 0.0, 'average': 0.3378378378378379}
# accuracy 0.5102040816326531
#
#
# Evaluación en el conjunto el conjunto to
# recall {'female': 1.0, 'male': 0.004866180048661801, 'average': 0.5024330900243309}
# precision {'female': 0.48227848101265824, 'male': 1.0, 'average': 0.7411392405063291}
# f1 {'female': 0.6507258753202392, 'male': 0.009685230024213076, 'average': 0.3302055526722261}
# accuracy 0.48358585858585856
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 1.0, 'male': 0.0025252525252525255, 'average': 0.5012626262626263}
# precision {'female': 0.48433420365535246, 'male': 1.0, 'average': 0.7421671018276762}
# f1 {'female': 0.6525945470536499, 'male': 0.005037783375314861, 'average': 0.3288161652144824}
# accuracy 0.485006518904824

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
save_path=f'simple_{model_name}_as2'

optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['to'],optimizer,early_stop=10,dl_val=dl_val['to'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.6934363396533275 	 Validation loss: 0.6936235043962123
#   1%|          | 574/57400 [01:33<2:27:31,  6.42it/s]
# Epoch 2 	 Training loss: 0.6935312110372537 	 Validation loss: 0.6929305791854858
#   2%|▏         | 1148/57400 [03:07<2:24:01,  6.51it/s]
# Epoch 3 	 Training loss: 0.6932797349911534 	 Validation loss: 0.6920020893468695
#   3%|▎         | 1722/57400 [04:41<2:31:15,  6.13it/s]
# Epoch 4 	 Training loss: 0.6933421489461373 	 Validation loss: 0.6940557249521805
#
# 1 epoch without improvement
#   4%|▍         | 2296/57400 [06:14<2:26:10,  6.28it/s]
# Epoch 5 	 Training loss: 0.693163118711332 	 Validation loss: 0.6936028650251486
#
# 2 epoch without improvement
#   5%|▌         | 2870/57400 [07:47<2:22:50,  6.36it/s]
# Epoch 6 	 Training loss: 0.6932655571852827 	 Validation loss: 0.6924511992325217
#
# 3 epoch without improvement
#   6%|▌         | 3444/57400 [09:20<2:19:42,  6.44it/s]
# Epoch 7 	 Training loss: 0.6931400906541206 	 Validation loss: 0.6930038009659719
#
# 4 epoch without improvement
#   7%|▋         | 4018/57400 [10:53<2:16:23,  6.52it/s]
# Epoch 8 	 Training loss: 0.6931295101027871 	 Validation loss: 0.6922336190433825
#
# 5 epoch without improvement
#   8%|▊         | 4592/57400 [12:25<2:23:17,  6.14it/s]
# Epoch 9 	 Training loss: 0.6930920873161808 	 Validation loss: 0.692811528504905
#
# 6 epoch without improvement
#   9%|▉         | 5166/57400 [13:58<2:17:58,  6.31it/s]
# Epoch 10 	 Training loss: 0.6930372662037507 	 Validation loss: 0.6924124289367158
#
# 7 epoch without improvement
#  10%|█         | 5740/57400 [15:31<2:12:16,  6.51it/s]
# Epoch 11 	 Training loss: 0.6928344813373446 	 Validation loss: 0.692736416550006
#
# 8 epoch without improvement
#  11%|█         | 6314/57400 [17:04<2:20:01,  6.08it/s]
# Epoch 12 	 Training loss: 0.6927456302302224 	 Validation loss: 0.6925550992205992
#
# 9 epoch without improvement
#  12%|█▏        | 6888/57400 [18:38<2:10:09,  6.47it/s]
# Epoch 13 	 Training loss: 0.6928249240336933 	 Validation loss: 0.6929508538569434
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 13 epochs...

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Evaluación en el conjunto el conjunto about
# c:\Users\FarinhOso\anaconda3\envs\tfg\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# recall {'female': 1.0, 'male': 0.0, 'average': 0.5}
# precision {'female': 0.5102040816326531, 'male': 0.0, 'average': 0.25510204081632654}
# f1 {'female': 0.6756756756756758, 'male': 0.0, 'average': 0.3378378378378379}
# accuracy 0.5102040816326531
#
#
# Evaluación en el conjunto el conjunto to
# c:\Users\FarinhOso\anaconda3\envs\tfg\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# recall {'female': 1.0, 'male': 0.0, 'average': 0.5}
# precision {'female': 0.4810606060606061, 'male': 0.0, 'average': 0.24053030303030304}
# f1 {'female': 0.6496163682864451, 'male': 0.0, 'average': 0.32480818414322254}
# accuracy 0.4810606060606061
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 1.0, 'male': 0.0, 'average': 0.5}
# precision {'female': 0.48370273794002605, 'male': 0.0, 'average': 0.24185136897001303}
# f1 {'female': 0.6520210896309314, 'male': 0.0, 'average': 0.3260105448154657}
# accuracy 0.48370273794002605
# c:\Users\FarinhOso\anaconda3\envs\tfg\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
save_path=f'simple_{model_name}_as3'

optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['to'],optimizer,early_stop=10,dl_val=dl_val['to'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.6949732556991045 	 Validation loss: 0.6914121771262864
#   1%|          | 574/57400 [01:34<2:29:30,  6.33it/s]
# Epoch 2 	 Training loss: 0.6945917152569269 	 Validation loss: 0.6934834152965222
#
# 1 epoch without improvement
#   2%|▏         | 1148/57400 [03:07<2:27:32,  6.35it/s]
# Epoch 3 	 Training loss: 0.6946106748298485 	 Validation loss: 0.6930672192977647
#
# 2 epoch without improvement
#   3%|▎         | 1722/57400 [04:40<2:20:43,  6.59it/s]
# Epoch 4 	 Training loss: 0.6947386397717307 	 Validation loss: 0.693214200310788
#
# 3 epoch without improvement
#   4%|▍         | 2296/57400 [06:13<2:18:33,  6.63it/s]
# Epoch 5 	 Training loss: 0.6943358391627202 	 Validation loss: 0.6931935659909653
#
# 4 epoch without improvement
#   5%|▌         | 2870/57400 [07:46<2:18:06,  6.58it/s]
# Epoch 6 	 Training loss: 0.6941086803579164 	 Validation loss: 0.6921385860039015
#
# 5 epoch without improvement
#   6%|▌         | 3444/57400 [09:19<2:19:17,  6.46it/s]
# Epoch 7 	 Training loss: 0.6940852033967341 	 Validation loss: 0.6937062831248267
#
# 6 epoch without improvement
#   7%|▋         | 4018/57400 [10:53<2:17:11,  6.48it/s]
# Epoch 8 	 Training loss: 0.6938934043724778 	 Validation loss: 0.6924263107574592
#
# 7 epoch without improvement
#   8%|▊         | 4592/57400 [12:26<2:13:03,  6.61it/s]
# Epoch 9 	 Training loss: 0.6942377804879112 	 Validation loss: 0.6925099461765613
#
# 8 epoch without improvement
#   9%|▉         | 5166/57400 [13:59<2:19:27,  6.24it/s]
# Epoch 10 	 Training loss: 0.6939343418601498 	 Validation loss: 0.6923708723763288
#
# 9 epoch without improvement
#  10%|█         | 5740/57400 [15:33<2:09:40,  6.64it/s]
# Epoch 11 	 Training loss: 0.6935123548898132 	 Validation loss: 0.6924086344444146
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 11 epochs...

# %%
model = st.SingleTaskSimple(model_conf,num_labels=num_labels).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Evaluación en el conjunto el conjunto about
# recall {'female': 0.9975, 'male': 0.0, 'average': 0.49875}
# precision {'female': 0.5095785440613027, 'male': 0.0, 'average': 0.2547892720306513}
# f1 {'female': 0.6745562130177516, 'male': 0.0, 'average': 0.3372781065088758}
# accuracy 0.5089285714285714
#
#
# Evaluación en el conjunto el conjunto to
# recall {'female': 0.994750656167979, 'male': 0.0024330900243309003, 'average': 0.49859187309615494}
# precision {'female': 0.4803548795944233, 'male': 0.3333333333333333, 'average': 0.4068441064638783}
# f1 {'female': 0.6478632478632478, 'male': 0.004830917874396136, 'average': 0.32634708286882197}
# accuracy 0.4797979797979798
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 1.0, 'male': 0.0025252525252525255, 'average': 0.5012626262626263}
# precision {'female': 0.48433420365535246, 'male': 1.0, 'average': 0.7421671018276762}
# f1 {'female': 0.6525945470536499, 'male': 0.005037783375314861, 'average': 0.3288161652144824}
# accuracy 0.485006518904824

# %% [markdown]
# Resultados finales

# %%
for metric in ['f1','recall','precision']:
    print(f'{metric} medio de los 3 modelos: \n')
    for task in ['about','to','as']:
        print(task.upper())
        print(f'Resultado global {metric}:',mean(global_metrics[task]['f1']['average']))
        print(f'{metric} etiqueta male:',mean(global_metrics[task]['f1']['male']))
        print(f'{metric} etiqueta female: ',mean(global_metrics[task]['f1']['female']))
        print('\n')

print(f'Accuracy medio de los 3 modelos: \n')
for task in ['about','to','as']:
    print('\n',task.upper())
    print('Resultado global accuracy:',mean(global_metrics[task]['acc']))
# Out:
# f1 medio de los 3 modelos:
#
# ABOUT
# Resultado global f1: 0.33765126072818386
# f1 etiqueta male: 0.0
# f1 etiqueta female:  0.6753025214563677
#
#
# TO
# Resultado global f1: 0.32712027322809023
# f1 etiqueta male: 0.00483871596620307
# f1 etiqueta female:  0.6494018304899773
#
#
# AS
# Resultado global f1: 0.3278809584148102
# f1 etiqueta male: 0.0033585222502099076
# f1 etiqueta female:  0.6524033945794104
#
#
# recall medio de los 3 modelos:
#
# ABOUT
# Resultado global recall: 0.33765126072818386
# recall etiqueta male: 0.0
# recall etiqueta female:  0.6753025214563677
#
#
# TO
# Resultado global recall: 0.32712027322809023
# recall etiqueta male: 0.00483871596620307
# recall etiqueta female:  0.6494018304899773
#
#
# AS
# Resultado global recall: 0.3278809584148102
# recall etiqueta male: 0.0033585222502099076
# recall etiqueta female:  0.6524033945794104
#
#
# precision medio de los 3 modelos:
#
# ABOUT
# Resultado global precision: 0.33765126072818386
# precision etiqueta male: 0.0
# precision etiqueta female:  0.6753025214563677
#
#
# TO
# Resultado global precision: 0.32712027322809023
# precision etiqueta male: 0.00483871596620307
# precision etiqueta female:  0.6494018304899773
#
#
# AS
# Resultado global precision: 0.3278809584148102
# precision etiqueta male: 0.0033585222502099076
# precision etiqueta female:  0.6524033945794104
#
#
# Accuracy medio de los 3 modelos:
#
#
#  ABOUT
# Resultado global accuracy: 0.5097789115646258
#
#  TO
# Resultado global accuracy: 0.48148148148148145
#
#  AS
# Resultado global accuracy: 0.48457192524989134
