# %%
import numpy as np
import torch


import json
from torch.utils.data import DataLoader
from torch.optim import AdamW
from torch import nn

from statistics import mean

# %%
import utils_generic as generic
import rrnn_modelo as rrnn

import train_datamaps_inprogress as train

from train import eval_func

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %% [markdown]
# # Datos ConvAI2

# %%
with open('Datasets\ConvAI2\convai2_complete.json','r') as f:
    data = json.load(f)

# %%
convai_train = data['train']
convai_val = data['validation']


word_to_index = generic.create_word_to_index(convai_train)

convai_train_token = generic.tokenize_dataset_rrnn(convai_train,['about','to','as'],word_to_index) 
convai_val_token = generic.tokenize_dataset_rrnn(convai_val,['about','to','as'],word_to_index)

# %%
convai_train_dataset = {}
for task in ['to','as','about']:
    convai_train_dataset[task] = rrnn.DatasetSingleTaskRRNN(convai_train_token,task,eval=False)

# %%
convai_val_dataset = {}
for task in ['to','as','about']:
    convai_val_dataset[task] = rrnn.DatasetSingleTaskRRNN(convai_val_token,task,eval=False)

# %% [markdown]
# # Datos md_gender

# %%
with open('Datasets\md_gender\md_complete.json','r',encoding="utf8") as f:
    md_data = json.load(f)

# %%
md_tokenized = generic.tokenize_dataset_rrnn(md_data,['about','to','as'],word_to_index) 


md_dataset = {}
for task in ['to','as','about']:
    md_dataset[task] = rrnn.DatasetSingleTaskRRNN(md_tokenized,task,eval=True)

# %% [markdown]
# # Creación dataloaders

# %%
dl_train = {}
for task in ['to','as','about']:
    dl_train[task] = DataLoader(convai_train_dataset[task],batch_size=128,shuffle=True,collate_fn=rrnn.collate_fn)

# %%
dl_val = {}
for task in ['to','as','about']:
    dl_val[task] = DataLoader(convai_val_dataset[task],batch_size=128,shuffle=True,collate_fn=rrnn.collate_fn)

# %%
dl_eval = {}
for task in ['to','as','about']:
    dl_eval[task] = DataLoader(md_dataset[task],batch_size=128,shuffle=False,collate_fn=rrnn.collate_fn)

# %%
emb_dim = 100
vocab_size = len(word_to_index)
num_labels = 2
lstm_hidden_dim = 128

# %% [markdown]
# ## ABOUT

# %%
learning_rate = 5e-5
num_epochs = 100

global_metrics = {'about':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]},
                    'to':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]},
                    'as':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]}}

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
save_path='m1_rrnn_simple_about_1'


optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['about'],optimizer,early_stop=10,dl_val=dl_val['about'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.6794428412091856 	 Validation loss: 0.6729293213052264
#   1%|          | 574/57400 [00:13<11:20, 83.53it/s]
# Epoch 2 	 Training loss: 0.6355723345113549 	 Validation loss: 0.6163774072113684
#   2%|▏         | 1148/57400 [00:20<10:55, 85.79it/s]
# Epoch 3 	 Training loss: 0.5953326962031554 	 Validation loss: 0.5857737468460859
#   3%|▎         | 1722/57400 [00:27<10:39, 87.10it/s]
# Epoch 4 	 Training loss: 0.5666717565018126 	 Validation loss: 0.5642469934487747
#   4%|▍         | 2296/57400 [00:34<10:43, 85.68it/s]
# Epoch 5 	 Training loss: 0.5433660779369002 	 Validation loss: 0.5515383416313236
#   5%|▌         | 2870/57400 [00:40<10:45, 84.46it/s]
# Epoch 6 	 Training loss: 0.5215803521850798 	 Validation loss: 0.529942684759528
#   6%|▌         | 3444/57400 [00:47<10:56, 82.15it/s]
# Epoch 7 	 Training loss: 0.5039080778065459 	 Validation loss: 0.5204166148678732
#   7%|▋         | 4018/57400 [00:54<10:08, 87.73it/s]
# Epoch 8 	 Training loss: 0.4876828170300361 	 Validation loss: 0.5034159800763858
#   8%|▊         | 4592/57400 [01:01<10:24, 84.56it/s]
# Epoch 9 	 Training loss: 0.4743353799764288 	 Validation loss: 0.4963656800278163
#   9%|▉         | 5166/57400 [01:08<09:54, 87.92it/s]
# Epoch 10 	 Training loss: 0.46211178320417834 	 Validation loss: 0.4916681374533702
#  10%|█         | 5740/57400 [01:14<09:49, 87.67it/s]
# Epoch 11 	 Training loss: 0.4520049893170699 	 Validation loss: 0.47999737323340724
#  11%|█         | 6314/57400 [01:21<09:47, 87.00it/s]
# Epoch 12 	 Training loss: 0.4429801811013072 	 Validation loss: 0.47307440638542175
#  12%|█▏        | 6888/57400 [01:28<10:05, 83.36it/s]
# Epoch 13 	 Training loss: 0.43425099250539256 	 Validation loss: 0.4743299140768536
#
# 1 epoch without improvement
#  13%|█▎        | 7462/57400 [01:35<10:16, 81.00it/s]
# Epoch 14 	 Training loss: 0.4267699695111152 	 Validation loss: 0.46618333155825986
#  14%|█▍        | 8036/57400 [01:42<10:11, 80.70it/s]
# Epoch 15 	 Training loss: 0.41891179745205603 	 Validation loss: 0.46194209739313286
#  15%|█▌        | 8610/57400 [01:49<09:40, 84.05it/s]
# Epoch 16 	 Training loss: 0.4122136508857747 	 Validation loss: 0.4606125319408158
#  16%|█▌        | 9184/57400 [01:56<09:21, 85.90it/s]
# Epoch 17 	 Training loss: 0.40516647950905127 	 Validation loss: 0.459815982539775
#  17%|█▋        | 9758/57400 [02:03<09:21, 84.89it/s]
# Epoch 18 	 Training loss: 0.4003557714954901 	 Validation loss: 0.46992853384906963
#
# 1 epoch without improvement
#  18%|█▊        | 10332/57400 [02:10<09:22, 83.70it/s]
# Epoch 19 	 Training loss: 0.3949476257226193 	 Validation loss: 0.4568940274796243
#  19%|█▉        | 10906/57400 [02:17<09:15, 83.68it/s]
# Epoch 20 	 Training loss: 0.3887988264033188 	 Validation loss: 0.4513457109362392
#  20%|██        | 11480/57400 [02:24<08:59, 85.06it/s]
# Epoch 21 	 Training loss: 0.3833545894988323 	 Validation loss: 0.4543541068747892
#
# 1 epoch without improvement
#  21%|██        | 12054/57400 [02:31<09:17, 81.30it/s]
# Epoch 22 	 Training loss: 0.38013264843188094 	 Validation loss: 0.4505697938345246
#  22%|██▏       | 12628/57400 [02:38<08:42, 85.76it/s]
# Epoch 23 	 Training loss: 0.37329999082283694 	 Validation loss: 0.44921717552815454
#  23%|██▎       | 13202/57400 [02:45<08:47, 83.82it/s]
# Epoch 24 	 Training loss: 0.3694690780045679 	 Validation loss: 0.4491780905400292
#  24%|██▍       | 13776/57400 [02:52<08:47, 82.68it/s]
# Epoch 25 	 Training loss: 0.3660097052099813 	 Validation loss: 0.4488637033155409
#  25%|██▌       | 14350/57400 [02:59<08:28, 84.66it/s]
# Epoch 26 	 Training loss: 0.3621674613825951 	 Validation loss: 0.4581702993077747
#
# 1 epoch without improvement
#  26%|██▌       | 14924/57400 [03:06<08:28, 83.61it/s]
# Epoch 27 	 Training loss: 0.3573286831378937 	 Validation loss: 0.44402695207272547
#  27%|██▋       | 15498/57400 [03:13<08:14, 84.73it/s]
# Epoch 28 	 Training loss: 0.3541680969271926 	 Validation loss: 0.4463610300573252
#
# 1 epoch without improvement
#  28%|██▊       | 16072/57400 [03:19<08:07, 84.71it/s]
# Epoch 29 	 Training loss: 0.3502118430434619 	 Validation loss: 0.45561321408061656
#
# 2 epoch without improvement
#  29%|██▉       | 16646/57400 [03:26<07:38, 88.87it/s]
# Epoch 30 	 Training loss: 0.34642513649285045 	 Validation loss: 0.4488320689080125
#
# 3 epoch without improvement
#  30%|███       | 17220/57400 [03:33<07:38, 87.56it/s]
# Epoch 31 	 Training loss: 0.34200230438119444 	 Validation loss: 0.4479976069119017
#
# 4 epoch without improvement
#  31%|███       | 17794/57400 [03:39<07:30, 87.93it/s]
# Epoch 32 	 Training loss: 0.3383342750656065 	 Validation loss: 0.4565531980183165
#
# 5 epoch without improvement
#  32%|███▏      | 18368/57400 [03:46<07:31, 86.54it/s]
# Epoch 33 	 Training loss: 0.33402253204521815 	 Validation loss: 0.44918500417369905
#
# 6 epoch without improvement
#  33%|███▎      | 18942/57400 [03:53<07:29, 85.50it/s]
# Epoch 34 	 Training loss: 0.33201018250985426 	 Validation loss: 0.44486439329082683
#
# 7 epoch without improvement
#  34%|███▍      | 19516/57400 [03:59<07:14, 87.18it/s]
# Epoch 35 	 Training loss: 0.3272467841254709 	 Validation loss: 0.4485418109570519
#
# 8 epoch without improvement
#  35%|███▌      | 20090/57400 [04:06<07:14, 85.83it/s]
# Epoch 36 	 Training loss: 0.32464784508382816 	 Validation loss: 0.4507683111449419
#
# 9 epoch without improvement
#  36%|███▌      | 20664/57400 [04:13<06:59, 87.66it/s]
# Epoch 37 	 Training loss: 0.3217887493947242 	 Validation loss: 0.44929291585744435
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 37 epochs...

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Evaluación en el conjunto el conjunto about
# recall {'female': 0.3875, 'male': 0.9322916666666666, 'average': 0.6598958333333333}
# precision {'female': 0.856353591160221, 'male': 0.593698175787728, 'average': 0.7250258834739745}
# f1 {'female': 0.5335628227194492, 'male': 0.7254305977710231, 'average': 0.6294967102452362}
# accuracy 0.6543367346938775
#
#
# Evaluación en el conjunto el conjunto to
# recall {'female': 0.23097112860892388, 'male': 0.8223844282238443, 'average': 0.5266777784163841}
# precision {'female': 0.546583850931677, 'male': 0.5356576862123613, 'average': 0.5411207685720192}
# f1 {'female': 0.3247232472324723, 'male': 0.6487523992322457, 'average': 0.48673782323235903}
# accuracy 0.5378787878787878
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 0.25336927223719674, 'male': 0.8585858585858586, 'average': 0.5559775654115277}
# precision {'female': 0.6266666666666667, 'male': 0.5510534846029174, 'average': 0.588860075634792}
# f1 {'female': 0.3608445297504798, 'male': 0.6712734452122409, 'average': 0.5160589874813604}
# accuracy 0.5658409387222947

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
save_path='m1_rrnn_simple_about_2'


optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['about'],optimizer,early_stop=10,dl_val=dl_val['about'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.676596138120113 	 Validation loss: 0.6636082742173793
#   1%|          | 574/57400 [00:06<10:58, 86.23it/s]
# Epoch 2 	 Training loss: 0.6312028292164155 	 Validation loss: 0.6166780964802887
#   2%|▏         | 1148/57400 [00:13<11:11, 83.79it/s]
# Epoch 3 	 Training loss: 0.5932046388915192 	 Validation loss: 0.582185115854619
#   3%|▎         | 1722/57400 [00:20<10:55, 84.95it/s]
# Epoch 4 	 Training loss: 0.5647663564943686 	 Validation loss: 0.5646059129197719
#   4%|▍         | 2296/57400 [00:27<10:43, 85.63it/s]
# Epoch 5 	 Training loss: 0.5398527465838588 	 Validation loss: 0.5444187870470144
#   5%|▌         | 2870/57400 [00:34<10:40, 85.14it/s]
# Epoch 6 	 Training loss: 0.5174663079324915 	 Validation loss: 0.5290966943158941
#   6%|▌         | 3444/57400 [00:40<10:26, 86.16it/s]
# Epoch 7 	 Training loss: 0.49828539632961727 	 Validation loss: 0.5218178230827137
#   7%|▋         | 4018/57400 [00:47<10:25, 85.38it/s]
# Epoch 8 	 Training loss: 0.48345477318306834 	 Validation loss: 0.5069231239415831
#   8%|▊         | 4592/57400 [00:54<10:09, 86.63it/s]
# Epoch 9 	 Training loss: 0.46948130543015976 	 Validation loss: 0.4977475561327853
#   9%|▉         | 5166/57400 [01:01<10:05, 86.25it/s]
# Epoch 10 	 Training loss: 0.45812007317559644 	 Validation loss: 0.4893117491471565
#  10%|█         | 5740/57400 [01:07<10:07, 85.00it/s]
# Epoch 11 	 Training loss: 0.44681729890328253 	 Validation loss: 0.4889928193415626
#  11%|█         | 6314/57400 [01:14<09:48, 86.73it/s]
# Epoch 12 	 Training loss: 0.4376036812411783 	 Validation loss: 0.4893170771962505
#
# 1 epoch without improvement
#  12%|█▏        | 6888/57400 [01:21<09:49, 85.73it/s]
# Epoch 13 	 Training loss: 0.4288837295479891 	 Validation loss: 0.4783331837694524
#  13%|█▎        | 7462/57400 [01:27<09:36, 86.60it/s]
# Epoch 14 	 Training loss: 0.4216735605994168 	 Validation loss: 0.4737738734584744
#  14%|█▍        | 8036/57400 [01:34<09:36, 85.56it/s]
# Epoch 15 	 Training loss: 0.41383588199831467 	 Validation loss: 0.47333541310439675
#  15%|█▌        | 8610/57400 [01:41<09:20, 86.98it/s]
# Epoch 16 	 Training loss: 0.4076694947917287 	 Validation loss: 0.4693779490761838
#  16%|█▌        | 9184/57400 [01:48<09:23, 85.55it/s]
# Epoch 17 	 Training loss: 0.401203874044302 	 Validation loss: 0.46754646553831586
#  17%|█▋        | 9758/57400 [01:54<09:12, 86.24it/s]
# Epoch 18 	 Training loss: 0.3949662481762391 	 Validation loss: 0.46927345607240323
#
# 1 epoch without improvement
#  18%|█▊        | 10332/57400 [02:01<09:01, 86.95it/s]
# Epoch 19 	 Training loss: 0.38983195251704095 	 Validation loss: 0.4686312963396816
#
# 2 epoch without improvement
#  19%|█▉        | 10906/57400 [02:08<08:56, 86.72it/s]
# Epoch 20 	 Training loss: 0.38486279028010284 	 Validation loss: 0.46188799051915186
#  20%|██        | 11480/57400 [02:14<08:54, 85.98it/s]
# Epoch 21 	 Training loss: 0.3798722856343831 	 Validation loss: 0.46354692669238073
#
# 1 epoch without improvement
#  21%|██        | 12054/57400 [02:21<08:38, 87.52it/s]
# Epoch 22 	 Training loss: 0.37316229760335295 	 Validation loss: 0.4598728696168479
#  22%|██▏       | 12628/57400 [02:28<08:41, 85.88it/s]
# Epoch 23 	 Training loss: 0.3692504410803941 	 Validation loss: 0.4572928184169834
#  23%|██▎       | 13202/57400 [02:35<08:28, 86.87it/s]
# Epoch 24 	 Training loss: 0.3661376796013802 	 Validation loss: 0.45802641066454225
#
# 1 epoch without improvement
#  24%|██▍       | 13776/57400 [02:41<08:32, 85.19it/s]
# Epoch 25 	 Training loss: 0.36045265270442495 	 Validation loss: 0.46484734143240974
#
# 2 epoch without improvement
#  25%|██▌       | 14350/57400 [02:48<08:05, 88.70it/s]
# Epoch 26 	 Training loss: 0.3566053616408687 	 Validation loss: 0.45735599731994886
#
# 3 epoch without improvement
#  26%|██▌       | 14924/57400 [02:55<08:29, 83.44it/s]
# Epoch 27 	 Training loss: 0.3529573919621494 	 Validation loss: 0.4560156575704025
#  27%|██▋       | 15498/57400 [03:01<08:05, 86.26it/s]
# Epoch 28 	 Training loss: 0.3479342120293956 	 Validation loss: 0.45671290664349573
#
# 1 epoch without improvement
#  28%|██▊       | 16072/57400 [03:08<08:02, 85.74it/s]
# Epoch 29 	 Training loss: 0.3444834669032994 	 Validation loss: 0.472704048884117
#
# 2 epoch without improvement
#  29%|██▉       | 16646/57400 [03:15<07:57, 85.41it/s]
# Epoch 30 	 Training loss: 0.34082767943679665 	 Validation loss: 0.45730842069043953
#
# 3 epoch without improvement
#  30%|███       | 17220/57400 [03:22<07:42, 86.82it/s]
# Epoch 31 	 Training loss: 0.33737561464932736 	 Validation loss: 0.4595611782397254
#
# 4 epoch without improvement
#  31%|███       | 17794/57400 [03:28<07:45, 85.07it/s]
# Epoch 32 	 Training loss: 0.33522045820016894 	 Validation loss: 0.45847743396031654
#
# 5 epoch without improvement
#  32%|███▏      | 18368/57400 [03:35<07:34, 85.83it/s]
# Epoch 33 	 Training loss: 0.3313487369424375 	 Validation loss: 0.4787407588150542
#
# 6 epoch without improvement
#  33%|███▎      | 18942/57400 [03:42<07:33, 84.76it/s]
# Epoch 34 	 Training loss: 0.3277815573877989 	 Validation loss: 0.46254126399250356
#
# 7 epoch without improvement
#  34%|███▍      | 19516/57400 [03:48<07:09, 88.28it/s]
# Epoch 35 	 Training loss: 0.32513495887717303 	 Validation loss: 0.4585447786218029
#
# 8 epoch without improvement
#  35%|███▌      | 20090/57400 [03:55<07:09, 86.87it/s]
# Epoch 36 	 Training loss: 0.3209519903938114 	 Validation loss: 0.4666312594534987
#
# 9 epoch without improvement
#  36%|███▌      | 20664/57400 [04:02<07:07, 85.92it/s]
# Epoch 37 	 Training loss: 0.31799906679146794 	 Validation loss: 0.46638115179740774
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 37 epochs...

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Evaluación en el conjunto el conjunto about
# recall {'female': 0.3825, 'male': 0.9453125, 'average': 0.66390625}
# precision {'female': 0.8793103448275862, 'male': 0.5950819672131148, 'average': 0.7371961560203505}
# f1 {'female': 0.5331010452961673, 'male': 0.7303822937625755, 'average': 0.6317416695293714}
# accuracy 0.6581632653061225
#
#
# Evaluación en el conjunto el conjunto to
# recall {'female': 0.2152230971128609, 'male': 0.8394160583941606, 'average': 0.5273195777535107}
# precision {'female': 0.5540540540540541, 'male': 0.5357142857142857, 'average': 0.5448841698841699}
# f1 {'female': 0.31001890359168244, 'male': 0.6540284360189574, 'average': 0.48202366980531997}
# accuracy 0.5391414141414141
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 0.18867924528301888, 'male': 0.8888888888888888, 'average': 0.5387840670859538}
# precision {'female': 0.6140350877192983, 'male': 0.5390505359877489, 'average': 0.5765428118535236}
# f1 {'female': 0.28865979381443296, 'male': 0.671115347950429, 'average': 0.479887570882431}
# accuracy 0.5501955671447197

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
save_path='m1_rrnn_simple_about_3'


optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['about'],optimizer,early_stop=10,dl_val=dl_val['about'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.677703765211205 	 Validation loss: 0.6701054633673975
#   1%|          | 574/57400 [00:06<10:51, 87.18it/s]
# Epoch 2 	 Training loss: 0.635791612315261 	 Validation loss: 0.6139240254790096
#   2%|▏         | 1148/57400 [00:13<10:44, 87.25it/s]
# Epoch 3 	 Training loss: 0.595657070079747 	 Validation loss: 0.5856820870253999
#   3%|▎         | 1722/57400 [00:20<11:02, 84.01it/s]
# Epoch 4 	 Training loss: 0.5647731633136497 	 Validation loss: 0.5641904215691453
#   4%|▍         | 2296/57400 [00:26<10:33, 86.93it/s]
# Epoch 5 	 Training loss: 0.5385209455411193 	 Validation loss: 0.5463087609258749
#   5%|▌         | 2870/57400 [00:33<10:29, 86.56it/s]
# Epoch 6 	 Training loss: 0.5151408023431326 	 Validation loss: 0.5281523385290372
#   6%|▌         | 3444/57400 [00:40<10:25, 86.28it/s]
# Epoch 7 	 Training loss: 0.4958974980726475 	 Validation loss: 0.5169905696885061
#   7%|▋         | 4018/57400 [00:47<10:08, 87.77it/s]
# Epoch 8 	 Training loss: 0.479280009398477 	 Validation loss: 0.5075018880730968
#   8%|▊         | 4592/57400 [00:53<10:19, 85.21it/s]
# Epoch 9 	 Training loss: 0.4646412686603825 	 Validation loss: 0.5055216308367454
#   9%|▉         | 5166/57400 [01:00<10:07, 86.02it/s]
# Epoch 10 	 Training loss: 0.45266436549221595 	 Validation loss: 0.5062269376496137
#
# 1 epoch without improvement
#  10%|█         | 5740/57400 [01:07<09:51, 87.38it/s]
# Epoch 11 	 Training loss: 0.4424568631196271 	 Validation loss: 0.4895526928416753
#  11%|█         | 6314/57400 [01:14<09:40, 87.97it/s]
# Epoch 12 	 Training loss: 0.4323366279697584 	 Validation loss: 0.48679951692031603
#  12%|█▏        | 6888/57400 [01:20<09:49, 85.64it/s]
# Epoch 13 	 Training loss: 0.4246713593861783 	 Validation loss: 0.48489646891416127
#  13%|█▎        | 7462/57400 [01:27<09:44, 85.42it/s]
# Epoch 14 	 Training loss: 0.41692368873112706 	 Validation loss: 0.4815169310165664
#  14%|█▍        | 8036/57400 [01:34<09:40, 85.00it/s]
# Epoch 15 	 Training loss: 0.410048888691211 	 Validation loss: 0.4798053821264687
#  15%|█▌        | 8610/57400 [01:41<09:21, 86.82it/s]
# Epoch 16 	 Training loss: 0.4037350825316399 	 Validation loss: 0.49342988103123037
#
# 1 epoch without improvement
#  16%|█▌        | 9184/57400 [01:47<09:09, 87.79it/s]
# Epoch 17 	 Training loss: 0.39725120633009836 	 Validation loss: 0.4873117925757069
#
# 2 epoch without improvement
#  17%|█▋        | 9758/57400 [01:54<09:06, 87.22it/s]
# Epoch 18 	 Training loss: 0.391565764822611 	 Validation loss: 0.47326838869159504
#  18%|█▊        | 10332/57400 [02:01<09:01, 86.91it/s]
# Epoch 19 	 Training loss: 0.3852953915500475 	 Validation loss: 0.4753751032433267
#
# 1 epoch without improvement
#  19%|█▉        | 10906/57400 [02:07<08:43, 88.83it/s]
# Epoch 20 	 Training loss: 0.38043133478339125 	 Validation loss: 0.47852054187806986
#
# 2 epoch without improvement
#  20%|██        | 11480/57400 [02:14<09:00, 84.93it/s]
# Epoch 21 	 Training loss: 0.37646289434582514 	 Validation loss: 0.4742258150698775
#
# 3 epoch without improvement
#  21%|██        | 12054/57400 [02:21<08:42, 86.85it/s]
# Epoch 22 	 Training loss: 0.37134527783672155 	 Validation loss: 0.47190166075350876
#  22%|██▏       | 12628/57400 [02:27<08:35, 86.90it/s]
# Epoch 23 	 Training loss: 0.36601014861038755 	 Validation loss: 0.473074622073416
#
# 1 epoch without improvement
#  23%|██▎       | 13202/57400 [02:34<08:41, 84.83it/s]
# Epoch 24 	 Training loss: 0.36104467656554246 	 Validation loss: 0.4719248828241381
#
# 2 epoch without improvement
#  24%|██▍       | 13776/57400 [02:41<08:24, 86.48it/s]
# Epoch 25 	 Training loss: 0.35806209780924825 	 Validation loss: 0.4712636531409571
#  25%|██▌       | 14350/57400 [02:48<08:09, 88.02it/s]
# Epoch 26 	 Training loss: 0.35314783591530463 	 Validation loss: 0.4677784175185834
#  26%|██▌       | 14924/57400 [02:54<08:16, 85.48it/s]
# Epoch 27 	 Training loss: 0.34918714293931 	 Validation loss: 0.47155483496391165
#
# 1 epoch without improvement
#  27%|██▋       | 15498/57400 [03:01<08:08, 85.83it/s]
# Epoch 28 	 Training loss: 0.3453687097137398 	 Validation loss: 0.46938053783723865
#
# 2 epoch without improvement
#  28%|██▊       | 16072/57400 [03:08<07:49, 88.11it/s]
# Epoch 29 	 Training loss: 0.3413939801554231 	 Validation loss: 0.4846879481259039
#
# 3 epoch without improvement
#  29%|██▉       | 16646/57400 [03:14<07:49, 86.82it/s]
# Epoch 30 	 Training loss: 0.33661474235589495 	 Validation loss: 0.47523899755235444
#
# 4 epoch without improvement
#  30%|███       | 17220/57400 [03:21<07:31, 88.92it/s]
# Epoch 31 	 Training loss: 0.3323380755267077 	 Validation loss: 0.4814884566654593
#
# 5 epoch without improvement
#  31%|███       | 17794/57400 [03:28<07:46, 84.88it/s]
# Epoch 32 	 Training loss: 0.3319387580511462 	 Validation loss: 0.4802906296010745
#
# 6 epoch without improvement
#  32%|███▏      | 18368/57400 [03:34<07:35, 85.77it/s]
# Epoch 33 	 Training loss: 0.32535702428855134 	 Validation loss: 0.4725212687152927
#
# 7 epoch without improvement
#  33%|███▎      | 18942/57400 [03:41<07:17, 87.98it/s]
# Epoch 34 	 Training loss: 0.3221467990908473 	 Validation loss: 0.4821799953105086
#
# 8 epoch without improvement
#  34%|███▍      | 19516/57400 [03:48<07:11, 87.79it/s]
# Epoch 35 	 Training loss: 0.3194649963532591 	 Validation loss: 0.4760538587125681
#
# 9 epoch without improvement
#  35%|███▌      | 20090/57400 [03:54<07:11, 86.56it/s]
# Epoch 36 	 Training loss: 0.3172248913435986 	 Validation loss: 0.47342490139654125
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 36 epochs...

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Evaluación en el conjunto el conjunto about
# recall {'female': 0.95, 'male': 0.2630208333333333, 'average': 0.6065104166666666}
# precision {'female': 0.5731523378582202, 'male': 0.8347107438016529, 'average': 0.7039315408299365}
# f1 {'female': 0.7149576669802445, 'male': 0.39999999999999997, 'average': 0.5574788334901223}
# accuracy 0.6135204081632653
#
#
# Evaluación en el conjunto el conjunto to
# recall {'female': 0.9081364829396326, 'male': 0.12165450121654502, 'average': 0.5148954920780888}
# precision {'female': 0.4893917963224894, 'male': 0.5882352941176471, 'average': 0.5388135452200682}
# f1 {'female': 0.636029411764706, 'male': 0.2016129032258065, 'average': 0.4188211574952562}
# accuracy 0.5
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 0.9380053908355795, 'male': 0.14898989898989898, 'average': 0.5434976449127392}
# precision {'female': 0.5080291970802919, 'male': 0.7195121951219512, 'average': 0.6137706961011216}
# f1 {'female': 0.6590909090909091, 'male': 0.24686192468619245, 'average': 0.4529764168885507}
# accuracy 0.530638852672751

# %%
for metric in ['f1','recall','precision']:
    print(f'{metric} medio de los 3 modelos: \n')
    for task in ['about','to','as']:
        print(task.upper())
        print(f'Resultado global {metric}:',mean(global_metrics[task][metric]['average']))
        print(f'{metric} etiqueta male:',mean(global_metrics[task][metric]['male']))
        print(f'{metric} etiqueta female: ',mean(global_metrics[task][metric]['female']))
        print('\n')

print(f'Accuracy medio de los 3 modelos: \n')
for task in ['about','to','as']:
    print('\n',task.upper())
    print('Resultado global accuracy:',mean(global_metrics[task]['acc']))
# Out:
# f1 medio de los 3 modelos:
#
# ABOUT
# Resultado global f1: 0.6062390710882433
# f1 etiqueta male: 0.6186042971778662
# f1 etiqueta female:  0.5938738449986204
#
#
# TO
# Resultado global f1: 0.4625275501776451
# f1 etiqueta male: 0.5014645794923366
# f1 etiqueta female:  0.42359052086295357
#
#
# AS
# Resultado global f1: 0.48297432508411403
# f1 etiqueta male: 0.5297502392829541
# f1 etiqueta female:  0.43619841088527395
#
#
# recall medio de los 3 modelos:
#
# ABOUT
# Resultado global recall: 0.6434375
# recall etiqueta male: 0.7135416666666666
# recall etiqueta female:  0.5733333333333334
#
#
# TO
# Resultado global recall: 0.5229642827493278
# recall etiqueta male: 0.5944849959448499
# recall etiqueta female:  0.45144356955380577
#
#
# AS
# Resultado global recall: 0.5460864258034069
# recall etiqueta male: 0.6321548821548821
# recall etiqueta female:  0.46001796945193174
#
#
# precision medio de los 3 modelos:
#
# ABOUT
# Resultado global precision: 0.7220511934414204
# precision etiqueta male: 0.6744969622674986
# precision etiqueta female:  0.7696054246153424
#
#
# TO
# Resultado global precision: 0.541606161225419
# precision etiqueta male: 0.5532024220147647
# precision etiqueta female:  0.5300099004360735
#
#
# AS
# Resultado global precision: 0.5930578611964791
# precision etiqueta male: 0.6032054052375392
# precision etiqueta female:  0.582910317155419
#
#
# Accuracy medio de los 3 modelos:
#
#
#  ABOUT
# Resultado global accuracy: 0.6420068027210885
#
#  TO
# Resultado global accuracy: 0.5256734006734006
#
#  AS
# Resultado global accuracy: 0.5488917861799218

# %% [markdown]
# ## TO

# %%
learning_rate = 5e-5
num_epochs = 100

global_metrics = {'about':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]},
                    'to':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]},
                    'as':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]}}

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
save_path='m1_rrnn_simple_to_1'


optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['to'],optimizer,early_stop=10,dl_val=dl_val['to'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.6933627386126369 	 Validation loss: 0.691546637122914
#   1%|          | 574/57400 [00:07<12:02, 78.67it/s]
# Epoch 2 	 Training loss: 0.6934626054680721 	 Validation loss: 0.6932067002280283
#
# 1 epoch without improvement
#   2%|▏         | 1148/57400 [00:14<11:26, 81.95it/s]
# Epoch 3 	 Training loss: 0.6931705624384332 	 Validation loss: 0.6943795731512167
#
# 2 epoch without improvement
#   3%|▎         | 1722/57400 [00:22<11:26, 81.16it/s]
# Epoch 4 	 Training loss: 0.6931232235780577 	 Validation loss: 0.6940127984952118
#
# 3 epoch without improvement
#   4%|▍         | 2296/57400 [00:29<11:17, 81.39it/s]
# Epoch 5 	 Training loss: 0.6931624827899999 	 Validation loss: 0.6925899931939982
#
# 4 epoch without improvement
#   5%|▌         | 2870/57400 [00:36<11:12, 81.03it/s]
# Epoch 6 	 Training loss: 0.6929548444025192 	 Validation loss: 0.6927588036504843
#
# 5 epoch without improvement
#   6%|▌         | 3444/57400 [00:43<11:10, 80.47it/s]
# Epoch 7 	 Training loss: 0.6927656857394175 	 Validation loss: 0.691946328696558
#
# 6 epoch without improvement
#   7%|▋         | 4018/57400 [00:51<10:56, 81.36it/s]
# Epoch 8 	 Training loss: 0.6928069078548444 	 Validation loss: 0.6935738405938876
#
# 7 epoch without improvement
#   8%|▊         | 4592/57400 [00:58<10:44, 81.94it/s]
# Epoch 9 	 Training loss: 0.6927554256409303 	 Validation loss: 0.6927782287031917
#
# 8 epoch without improvement
#   9%|▉         | 5166/57400 [01:05<10:46, 80.78it/s]
# Epoch 10 	 Training loss: 0.692637852675408 	 Validation loss: 0.6926356493416479
#
# 9 epoch without improvement
#  10%|█         | 5740/57400 [01:12<10:30, 81.95it/s]
# Epoch 11 	 Training loss: 0.6926593741058057 	 Validation loss: 0.6932535181611271
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 11 epochs...

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Evaluación en el conjunto el conjunto about
# recall {'female': 0.515, 'male': 0.4921875, 'average': 0.5035937500000001}
# precision {'female': 0.513715710723192, 'male': 0.4934725848563969, 'average': 0.5035941477897945}
# f1 {'female': 0.5143570536828964, 'male': 0.49282920469361147, 'average': 0.5035931291882539}
# accuracy 0.5038265306122449
#
#
# Evaluación en el conjunto el conjunto to
# recall {'female': 0.49343832020997375, 'male': 0.5620437956204379, 'average': 0.5277410579152059}
# precision {'female': 0.5108695652173914, 'male': 0.5448113207547169, 'average': 0.5278404429860541}
# f1 {'female': 0.5020026702269693, 'male': 0.5532934131736528, 'average': 0.5276480417003111}
# accuracy 0.5290404040404041
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 0.4743935309973046, 'male': 0.5732323232323232, 'average': 0.5238129271148139}
# precision {'female': 0.5101449275362319, 'male': 0.5379146919431279, 'average': 0.5240298097396798}
# f1 {'female': 0.49162011173184356, 'male': 0.5550122249388754, 'average': 0.5233161683353594}
# accuracy 0.5254237288135594

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
save_path='m1_rrnn_simple_to_2'


optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['to'],optimizer,early_stop=10,dl_val=dl_val['to'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.6935935604032324 	 Validation loss: 0.6927529765387713
#   1%|          | 574/57400 [00:07<11:35, 81.69it/s]
# Epoch 2 	 Training loss: 0.6931538381435315 	 Validation loss: 0.6940368060338296
#
# 1 epoch without improvement
#   2%|▏         | 1148/57400 [00:14<11:24, 82.15it/s]
# Epoch 3 	 Training loss: 0.6932696444647652 	 Validation loss: 0.6934631820452415
#
# 2 epoch without improvement
#   3%|▎         | 1722/57400 [00:21<11:18, 82.02it/s]
# Epoch 4 	 Training loss: 0.6930995091328638 	 Validation loss: 0.6930045030884824
#
# 3 epoch without improvement
#   4%|▍         | 2296/57400 [00:29<11:41, 78.61it/s]
# Epoch 5 	 Training loss: 0.6929283735021066 	 Validation loss: 0.6935453950348547
#
# 4 epoch without improvement
#   5%|▌         | 2870/57400 [00:36<11:05, 81.89it/s]
# Epoch 6 	 Training loss: 0.6929756027065503 	 Validation loss: 0.6931031710010463
#
# 5 epoch without improvement
#   6%|▌         | 3444/57400 [00:43<11:25, 78.70it/s]
# Epoch 7 	 Training loss: 0.6929763559680368 	 Validation loss: 0.6928909370454691
#
# 6 epoch without improvement
#   7%|▋         | 4018/57400 [00:50<10:55, 81.44it/s]
# Epoch 8 	 Training loss: 0.692662918505353 	 Validation loss: 0.694121633545827
#
# 7 epoch without improvement
#   8%|▊         | 4592/57400 [00:58<11:20, 77.62it/s]
# Epoch 9 	 Training loss: 0.6927400767180147 	 Validation loss: 0.6931455589957156
#
# 8 epoch without improvement
#   9%|▉         | 5166/57400 [01:05<10:41, 81.41it/s]
# Epoch 10 	 Training loss: 0.6926143795563369 	 Validation loss: 0.6933698654174805
#
# 9 epoch without improvement
#  10%|█         | 5740/57400 [01:12<10:24, 82.67it/s]
# Epoch 11 	 Training loss: 0.6924769574133777 	 Validation loss: 0.6944763609918497
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 11 epochs...

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Evaluación en el conjunto el conjunto about
# recall {'female': 0.92, 'male': 0.08854166666666667, 'average': 0.5042708333333333}
# precision {'female': 0.5125348189415042, 'male': 0.5151515151515151, 'average': 0.5138431670465097}
# f1 {'female': 0.6583184257602862, 'male': 0.1511111111111111, 'average': 0.40471476843569865}
# accuracy 0.5127551020408163
#
#
# Evaluación en el conjunto el conjunto to
# recall {'female': 0.9448818897637795, 'male': 0.06569343065693431, 'average': 0.5052876602103569}
# precision {'female': 0.4838709677419355, 'male': 0.5625, 'average': 0.5231854838709677}
# f1 {'female': 0.6399999999999999, 'male': 0.11764705882352941, 'average': 0.37882352941176467}
# accuracy 0.48863636363636365
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 0.9137466307277629, 'male': 0.05303030303030303, 'average': 0.4833884668790329}
# precision {'female': 0.47478991596638653, 'male': 0.39622641509433965, 'average': 0.4355081655303631}
# f1 {'female': 0.6248847926267281, 'male': 0.0935412026726058, 'average': 0.35921299764966697}
# accuracy 0.46936114732724904

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
save_path='m1_rrnn_simple_to_3'


optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['to'],optimizer,early_stop=10,dl_val=dl_val['to'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.6937204138327143 	 Validation loss: 0.6929909344446861
#   1%|          | 574/57400 [00:07<11:41, 80.99it/s]
# Epoch 2 	 Training loss: 0.6934138358885403 	 Validation loss: 0.6921228382547023
#   2%|▏         | 1148/57400 [00:14<11:39, 80.42it/s]
# Epoch 3 	 Training loss: 0.6932548980264298 	 Validation loss: 0.6924623857110234
#
# 1 epoch without improvement
#   3%|▎         | 1722/57400 [00:22<11:22, 81.54it/s]
# Epoch 4 	 Training loss: 0.6930595958274416 	 Validation loss: 0.6935468184745918
#
# 2 epoch without improvement
#   4%|▍         | 2296/57400 [00:29<11:07, 82.50it/s]
# Epoch 5 	 Training loss: 0.6929731122915753 	 Validation loss: 0.6934309066352198
#
# 3 epoch without improvement
#   5%|▌         | 2870/57400 [00:36<11:11, 81.24it/s]
# Epoch 6 	 Training loss: 0.6929431525464672 	 Validation loss: 0.6920954756817576
#   6%|▌         | 3444/57400 [00:44<11:20, 79.34it/s]
# Epoch 7 	 Training loss: 0.6929304433616612 	 Validation loss: 0.693887849985543
#
# 1 epoch without improvement
#   7%|▋         | 4018/57400 [00:51<10:49, 82.18it/s]
# Epoch 8 	 Training loss: 0.6927572790961648 	 Validation loss: 0.6942855281344915
#
# 2 epoch without improvement
#   8%|▊         | 4592/57400 [00:58<10:47, 81.58it/s]
# Epoch 9 	 Training loss: 0.6927546306354243 	 Validation loss: 0.6931455034320637
#
# 3 epoch without improvement
#   9%|▉         | 5166/57400 [01:05<10:39, 81.68it/s]
# Epoch 10 	 Training loss: 0.6926581010170515 	 Validation loss: 0.6936996518555334
#
# 4 epoch without improvement
#  10%|█         | 5740/57400 [01:13<10:41, 80.58it/s]
# Epoch 11 	 Training loss: 0.6926212557932225 	 Validation loss: 0.6941721308029304
#
# 5 epoch without improvement
#  11%|█         | 6314/57400 [01:20<10:20, 82.29it/s]
# Epoch 12 	 Training loss: 0.6925637951503647 	 Validation loss: 0.6934282739283675
#
# 6 epoch without improvement
#  12%|█▏        | 6888/57400 [01:27<10:36, 79.32it/s]
# Epoch 13 	 Training loss: 0.692468956891668 	 Validation loss: 0.6934465159804134
#
# 7 epoch without improvement
#  13%|█▎        | 7462/57400 [01:35<10:19, 80.66it/s]
# Epoch 14 	 Training loss: 0.6924595955356904 	 Validation loss: 0.6931058138103808
#
# 8 epoch without improvement
#  14%|█▍        | 8036/57400 [01:42<10:01, 82.02it/s]
# Epoch 15 	 Training loss: 0.6923378401724719 	 Validation loss: 0.6931793649317854
#
# 9 epoch without improvement
#  15%|█▌        | 8610/57400 [01:49<10:08, 80.24it/s]
# Epoch 16 	 Training loss: 0.69214886468462 	 Validation loss: 0.6937630328081422
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 16 epochs...

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Evaluación en el conjunto el conjunto about
# recall {'female': 0.8925, 'male': 0.125, 'average': 0.50875}
# precision {'female': 0.5151515151515151, 'male': 0.5274725274725275, 'average': 0.5213120213120213}
# f1 {'female': 0.6532479414455625, 'male': 0.20210526315789473, 'average': 0.42767660230172866}
# accuracy 0.5165816326530612
#
#
# Evaluación en el conjunto el conjunto to
# recall {'female': 0.8871391076115486, 'male': 0.09002433090024331, 'average': 0.48858171925589594}
# precision {'female': 0.4747191011235955, 'male': 0.4625, 'average': 0.46860955056179776}
# f1 {'female': 0.6184812442817932, 'male': 0.15071283095723012, 'average': 0.38459703761951164}
# accuracy 0.4734848484848485
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 0.9083557951482479, 'male': 0.09848484848484848, 'average': 0.5034203218165482}
# precision {'female': 0.48559077809798273, 'male': 0.5342465753424658, 'average': 0.5099186767202243}
# f1 {'female': 0.6328638497652582, 'male': 0.16631130063965885, 'average': 0.3995875752024585}
# accuracy 0.49022164276401564

# %%
for metric in ['f1','recall','precision']:
    print(f'{metric} medio de los 3 modelos: \n')
    for task in ['about','to','as']:
        print(task.upper())
        print(f'Resultado global {metric}:',mean(global_metrics[task][metric]['average']))
        print(f'{metric} etiqueta male:',mean(global_metrics[task][metric]['male']))
        print(f'{metric} etiqueta female: ',mean(global_metrics[task][metric]['female']))
        print('\n')

print(f'Accuracy medio de los 3 modelos: \n')
for task in ['about','to','as']:
    print('\n',task.upper())
    print('Resultado global accuracy:',mean(global_metrics[task]['acc']))
# Out:
# f1 medio de los 3 modelos:
#
# ABOUT
# Resultado global f1: 0.44532816664189373
# f1 etiqueta male: 0.2820151929875391
# f1 etiqueta female:  0.6086411402962484
#
#
# TO
# Resultado global f1: 0.4303562029105291
# f1 etiqueta male: 0.2738844343181374
# f1 etiqueta female:  0.5868279715029208
#
#
# AS
# Resultado global f1: 0.427372247062495
# f1 etiqueta male: 0.27162157608371335
# f1 etiqueta female:  0.5831229180412767
#
#
# recall medio de los 3 modelos:
#
# ABOUT
# Resultado global recall: 0.5055381944444445
# recall etiqueta male: 0.23524305555555555
# recall etiqueta female:  0.7758333333333334
#
#
# TO
# Resultado global recall: 0.5072034791271529
# recall etiqueta male: 0.23925385239253852
# recall etiqueta female:  0.7751531058617673
#
#
# AS
# Resultado global recall: 0.5035405719367984
# recall etiqueta male: 0.24158249158249157
# recall etiqueta female:  0.7654986522911051
#
#
# precision medio de los 3 modelos:
#
# ABOUT
# Resultado global precision: 0.5129164453827751
# precision etiqueta male: 0.5120322091601465
# precision etiqueta female:  0.5138006816054038
#
#
# TO
# Resultado global precision: 0.5065451591396065
# precision etiqueta male: 0.5232704402515723
# precision etiqueta female:  0.48981987802764076
#
#
# AS
# Resultado global precision: 0.4898188839967557
# precision etiqueta male: 0.48946256079331113
# precision etiqueta female:  0.49017520720020036
#
#
# Accuracy medio de los 3 modelos:
#
#
#  ABOUT
# Resultado global accuracy: 0.5110544217687075
#
#  TO
# Resultado global accuracy: 0.4970538720538721
#
#  AS
# Resultado global accuracy: 0.4950021729682747

# %% [markdown]
# ## AS

# %%
learning_rate = 5e-5
num_epochs = 100

global_metrics = {'about':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]},
                    'to':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]},
                    'as':{'recall':{'average':[],'female':[],'male':[]},
                            'precision':{'average':[],'female':[],'male':[]},
                            'f1':{'average':[],'female':[],'male':[]},
                            'acc':[]}}

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
save_path='m1_rrnn_simple_as_1'


optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['as'],optimizer,early_stop=10,dl_val=dl_val['as'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.693395045056991 	 Validation loss: 0.6926209451788563
#   1%|          | 574/57400 [00:07<11:34, 81.79it/s]
# Epoch 2 	 Training loss: 0.6930881247495525 	 Validation loss: 0.6941503185336872
#
# 1 epoch without improvement
#   2%|▏         | 1148/57400 [00:14<11:27, 81.84it/s]
# Epoch 3 	 Training loss: 0.6928749312922514 	 Validation loss: 0.6939507318755328
#
# 2 epoch without improvement
#   3%|▎         | 1722/57400 [00:22<11:22, 81.52it/s]
# Epoch 4 	 Training loss: 0.6929079298358346 	 Validation loss: 0.6931697897991892
#
# 3 epoch without improvement
#   4%|▍         | 2296/57400 [00:29<11:11, 82.02it/s]
# Epoch 5 	 Training loss: 0.692681380161425 	 Validation loss: 0.6935917411820364
#
# 4 epoch without improvement
#   5%|▌         | 2870/57400 [00:36<11:04, 82.10it/s]
# Epoch 6 	 Training loss: 0.6923682582710678 	 Validation loss: 0.6924563383651992
#   6%|▌         | 3444/57400 [00:43<11:18, 79.47it/s]
# Epoch 7 	 Training loss: 0.6918425312856349 	 Validation loss: 0.6941723358833184
#
# 1 epoch without improvement
#   7%|▋         | 4018/57400 [00:51<11:15, 79.01it/s]
# Epoch 8 	 Training loss: 0.6914013684418974 	 Validation loss: 0.6922504720041307
#   8%|▊         | 4592/57400 [00:58<10:44, 81.90it/s]
# Epoch 9 	 Training loss: 0.6912112250560667 	 Validation loss: 0.6952415169295618
#
# 1 epoch without improvement
#   9%|▉         | 5166/57400 [01:05<10:36, 82.03it/s]
# Epoch 10 	 Training loss: 0.6905014586573278 	 Validation loss: 0.6953601523981257
#
# 2 epoch without improvement
#  10%|█         | 5740/57400 [01:13<10:31, 81.76it/s]
# Epoch 11 	 Training loss: 0.6898235037974779 	 Validation loss: 0.6940792122129666
#
# 3 epoch without improvement
#  11%|█         | 6314/57400 [01:20<10:33, 80.70it/s]
# Epoch 12 	 Training loss: 0.6893066581117983 	 Validation loss: 0.6961099818601446
#
# 4 epoch without improvement
#  12%|█▏        | 6888/57400 [01:27<10:46, 78.17it/s]
# Epoch 13 	 Training loss: 0.6885182268735839 	 Validation loss: 0.695185866396306
#
# 5 epoch without improvement
#  13%|█▎        | 7462/57400 [01:35<10:09, 81.94it/s]
# Epoch 14 	 Training loss: 0.6880295355560888 	 Validation loss: 0.6919469752554166
#  14%|█▍        | 8036/57400 [01:42<10:07, 81.25it/s]
# Epoch 15 	 Training loss: 0.686736480699599 	 Validation loss: 0.6944522867768498
#
# 1 epoch without improvement
#  15%|█▌        | 8610/57400 [01:49<10:13, 79.47it/s]
# Epoch 16 	 Training loss: 0.6867068531413527 	 Validation loss: 0.6950635101835606
#
# 2 epoch without improvement
#  16%|█▌        | 9184/57400 [01:57<10:04, 79.79it/s]
# Epoch 17 	 Training loss: 0.685648827602639 	 Validation loss: 0.693599461498907
#
# 3 epoch without improvement
#  17%|█▋        | 9758/57400 [02:04<09:40, 82.04it/s]
# Epoch 18 	 Training loss: 0.6850989014429498 	 Validation loss: 0.6959751864611092
#
# 4 epoch without improvement
#  18%|█▊        | 10332/57400 [02:11<09:35, 81.83it/s]
# Epoch 19 	 Training loss: 0.68480702061271 	 Validation loss: 0.6963560177107989
#
# 5 epoch without improvement
#  19%|█▉        | 10906/57400 [02:19<09:43, 79.74it/s]
# Epoch 20 	 Training loss: 0.6840388176748562 	 Validation loss: 0.694829532655619
#
# 6 epoch without improvement
#  20%|██        | 11480/57400 [02:26<09:23, 81.43it/s]
# Epoch 21 	 Training loss: 0.6836265009870097 	 Validation loss: 0.69386257660591
#
# 7 epoch without improvement
#  21%|██        | 12054/57400 [02:33<09:23, 80.54it/s]
# Epoch 22 	 Training loss: 0.6833571437551584 	 Validation loss: 0.695960913674306
#
# 8 epoch without improvement
#  22%|██▏       | 12628/57400 [02:40<09:17, 80.27it/s]
# Epoch 23 	 Training loss: 0.6825329807784914 	 Validation loss: 0.6964921223915229
#
# 9 epoch without improvement
#  23%|██▎       | 13202/57400 [02:48<09:20, 78.85it/s]
# Epoch 24 	 Training loss: 0.6820514708861242 	 Validation loss: 0.6972497762259791
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 24 epochs...

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Evaluación en el conjunto el conjunto about
# recall {'female': 0.175, 'male': 0.7708333333333334, 'average': 0.47291666666666665}
# precision {'female': 0.4430379746835443, 'male': 0.4728434504792332, 'average': 0.45794071258138874}
# f1 {'female': 0.25089605734767023, 'male': 0.5861386138613861, 'average': 0.4185173356045282}
# accuracy 0.46683673469387754
#
#
# Evaluación en el conjunto el conjunto to
# recall {'female': 0.1968503937007874, 'male': 0.8248175182481752, 'average': 0.5108339559744813}
# precision {'female': 0.5102040816326531, 'male': 0.5255813953488372, 'average': 0.5178927384907451}
# f1 {'female': 0.2840909090909091, 'male': 0.6420454545454545, 'average': 0.46306818181818177}
# accuracy 0.5227272727272727
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 0.20215633423180593, 'male': 0.8232323232323232, 'average': 0.5126943287320646}
# precision {'female': 0.5172413793103449, 'male': 0.5241157556270096, 'average': 0.5206785674686772}
# f1 {'female': 0.29069767441860467, 'male': 0.6404715127701375, 'average': 0.4655845935943711}
# accuracy 0.5228161668839635

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
save_path='m1_rrnn_simple_as_2'


optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['as'],optimizer,early_stop=10,dl_val=dl_val['as'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.6934750601389682 	 Validation loss: 0.6930891467353045
#   1%|          | 574/57400 [00:07<11:29, 82.46it/s]
# Epoch 2 	 Training loss: 0.693170411557686 	 Validation loss: 0.6938082343440944
#
# 1 epoch without improvement
#   2%|▏         | 1148/57400 [00:14<11:29, 81.56it/s]
# Epoch 3 	 Training loss: 0.6931778167598339 	 Validation loss: 0.693235205391706
#
# 2 epoch without improvement
#   3%|▎         | 1722/57400 [00:21<11:15, 82.40it/s]
# Epoch 4 	 Training loss: 0.6927154520039774 	 Validation loss: 0.6941291265568491
#
# 3 epoch without improvement
#   4%|▍         | 2296/57400 [00:29<11:09, 82.31it/s]
# Epoch 5 	 Training loss: 0.6926880030266499 	 Validation loss: 0.6920664957014181
#   5%|▌         | 2870/57400 [00:36<11:33, 78.69it/s]
# Epoch 6 	 Training loss: 0.6924975215350294 	 Validation loss: 0.6932495933468059
#
# 1 epoch without improvement
#   6%|▌         | 3444/57400 [00:43<11:06, 80.91it/s]
# Epoch 7 	 Training loss: 0.6921792036564923 	 Validation loss: 0.694225088014441
#
# 2 epoch without improvement
#   7%|▋         | 4018/57400 [00:51<10:50, 82.10it/s]
# Epoch 8 	 Training loss: 0.6921256665361052 	 Validation loss: 0.6926902168888157
#
# 3 epoch without improvement
#   8%|▊         | 4592/57400 [00:58<10:48, 81.44it/s]
# Epoch 9 	 Training loss: 0.691340664226419 	 Validation loss: 0.692882724737717
#
# 4 epoch without improvement
#   9%|▉         | 5166/57400 [01:05<10:51, 80.15it/s]
# Epoch 10 	 Training loss: 0.6909840591900855 	 Validation loss: 0.6928914270158542
#
# 5 epoch without improvement
#  10%|█         | 5740/57400 [01:12<10:47, 79.78it/s]
# Epoch 11 	 Training loss: 0.6905316646090783 	 Validation loss: 0.6950318772914046
#
# 6 epoch without improvement
#  11%|█         | 6314/57400 [01:20<10:44, 79.29it/s]
# Epoch 12 	 Training loss: 0.6895112152298983 	 Validation loss: 0.6959964309708547
#
# 7 epoch without improvement
#  12%|█▏        | 6888/57400 [01:27<10:33, 79.75it/s]
# Epoch 13 	 Training loss: 0.6884921058129766 	 Validation loss: 0.6939314149193845
#
# 8 epoch without improvement
#  13%|█▎        | 7462/57400 [01:34<10:24, 80.02it/s]
# Epoch 14 	 Training loss: 0.6878150952817671 	 Validation loss: 0.695700489868552
#
# 9 epoch without improvement
#  14%|█▍        | 8036/57400 [01:42<10:01, 82.03it/s]
# Epoch 15 	 Training loss: 0.687757600059908 	 Validation loss: 0.694341060468706
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 15 epochs...

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Evaluación en el conjunto el conjunto about
# recall {'female': 0.96, 'male': 0.036458333333333336, 'average': 0.49822916666666667}
# precision {'female': 0.5092838196286472, 'male': 0.4666666666666667, 'average': 0.48797524314765695}
# f1 {'female': 0.6655112651646448, 'male': 0.0676328502415459, 'average': 0.3665720577030953}
# accuracy 0.5076530612244898
#
#
# Evaluación en el conjunto el conjunto to
# recall {'female': 0.9711286089238845, 'male': 0.024330900243309004, 'average': 0.49772975458359675}
# precision {'female': 0.4798962386511025, 'male': 0.47619047619047616, 'average': 0.4780433574207893}
# f1 {'female': 0.6423611111111112, 'male': 0.0462962962962963, 'average': 0.3443287037037037}
# accuracy 0.4797979797979798
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 0.9703504043126685, 'male': 0.03787878787878788, 'average': 0.5041145960957282}
# precision {'female': 0.48582995951417, 'male': 0.5769230769230769, 'average': 0.5313765182186234}
# f1 {'female': 0.6474820143884893, 'male': 0.07109004739336494, 'average': 0.35928603089092714}
# accuracy 0.48891786179921776

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
save_path='m1_rrnn_simple_as_3'


optimizer = AdamW(model.parameters(), lr=learning_rate,weight_decay=0.1)
p = train.train_function(model,num_epochs,dl_train['as'],optimizer,early_stop=10,dl_val=dl_val['as'],save_path=save_path,es_threshold=0)
torch.save(p,save_path+'.pt')
# Out:
#   0%|          | 0/57400 [00:00<?, ?it/s]
# Epoch 1 	 Training loss: 0.6936908542902213 	 Validation loss: 0.6924328763606185
#   1%|          | 574/57400 [00:07<11:31, 82.12it/s]
# Epoch 2 	 Training loss: 0.6933552062054544 	 Validation loss: 0.693422108383502
#
# 1 epoch without improvement
#   2%|▏         | 1148/57400 [00:14<11:28, 81.68it/s]
# Epoch 3 	 Training loss: 0.6932674496846747 	 Validation loss: 0.6931095982002
#
# 2 epoch without improvement
#   3%|▎         | 1722/57400 [00:21<11:19, 82.00it/s]
# Epoch 4 	 Training loss: 0.6929420945121021 	 Validation loss: 0.692810781931473
#
# 3 epoch without improvement
#   4%|▍         | 2296/57400 [00:29<11:25, 80.39it/s]
# Epoch 5 	 Training loss: 0.6926425557310988 	 Validation loss: 0.6932594311439385
#
# 4 epoch without improvement
#   5%|▌         | 2870/57400 [00:36<11:01, 82.47it/s]
# Epoch 6 	 Training loss: 0.6926954651335806 	 Validation loss: 0.6915887998322309
#   6%|▌         | 3444/57400 [00:43<11:01, 81.57it/s]
# Epoch 7 	 Training loss: 0.6922875222221069 	 Validation loss: 0.6933859101796555
#
# 1 epoch without improvement
#   7%|▋         | 4018/57400 [00:51<10:58, 81.10it/s]
# Epoch 8 	 Training loss: 0.6920492197370696 	 Validation loss: 0.6943377892849809
#
# 2 epoch without improvement
#   8%|▊         | 4592/57400 [00:58<10:43, 82.10it/s]
# Epoch 9 	 Training loss: 0.6916727790226089 	 Validation loss: 0.6935408135591927
#
# 3 epoch without improvement
#   9%|▉         | 5166/57400 [01:05<10:40, 81.62it/s]
# Epoch 10 	 Training loss: 0.6909812301501165 	 Validation loss: 0.6931590367171724
#
# 4 epoch without improvement
#  10%|█         | 5740/57400 [01:13<10:47, 79.73it/s]
# Epoch 11 	 Training loss: 0.6907820973662134 	 Validation loss: 0.6954158372798208
#
# 5 epoch without improvement
#  11%|█         | 6314/57400 [01:20<10:24, 81.75it/s]
# Epoch 12 	 Training loss: 0.6900390865287714 	 Validation loss: 0.6955502972764483
#
# 6 epoch without improvement
#  12%|█▏        | 6888/57400 [01:27<10:30, 80.07it/s]
# Epoch 13 	 Training loss: 0.6891249982114452 	 Validation loss: 0.6942204570366164
#
# 7 epoch without improvement
#  13%|█▎        | 7462/57400 [01:35<10:15, 81.17it/s]
# Epoch 14 	 Training loss: 0.6890496236729705 	 Validation loss: 0.6927806007660041
#
# 8 epoch without improvement
#  14%|█▍        | 8036/57400 [01:42<10:00, 82.21it/s]
# Epoch 15 	 Training loss: 0.688740445346367 	 Validation loss: 0.6946056697328212
#
# 9 epoch without improvement
#  15%|█▌        | 8610/57400 [01:49<09:59, 81.44it/s]
# Epoch 16 	 Training loss: 0.6879952978797075 	 Validation loss: 0.6943040853839809
#
# 10 epoch without improvement
# Validation_loss hasn't improve in 10 epoch. Stopping training after 16 epochs...

# %%
model = rrnn.SingleTaskRRNN(vocab_size = vocab_size,emb_dim=emb_dim,lstm_hidden_dim = lstm_hidden_dim).to(device)
model.load_state_dict(torch.load(save_path))
for task in ['about','to','as']:
    print('\n')
    print(f"Evaluación en el conjunto el conjunto {task}")
    metric_result = eval_func(model,dl_eval[task])
    for metric, value in metric_result.items():
        if metric=='accuracy':
            global_metrics[task]['acc'].append(value) 
        else:
            for g,v in value.items():
                global_metrics[task][metric][g].append(v)

        print(metric,metric_result[metric])
# Out:
# Evaluación en el conjunto el conjunto about
# recall {'female': 0.4525, 'male': 0.6197916666666666, 'average': 0.5361458333333333}
# precision {'female': 0.5535168195718655, 'male': 0.5207877461706784, 'average': 0.5371522828712719}
# f1 {'female': 0.4979367262723522, 'male': 0.5659928656361474, 'average': 0.5319647959542497}
# accuracy 0.5344387755102041
#
#
# Evaluación en el conjunto el conjunto to
# recall {'female': 0.3858267716535433, 'male': 0.635036496350365, 'average': 0.5104316340019541}
# precision {'female': 0.494949494949495, 'male': 0.5272727272727272, 'average': 0.5111111111111111}
# f1 {'female': 0.4336283185840708, 'male': 0.576158940397351, 'average': 0.5048936294907109}
# accuracy 0.5151515151515151
#
#
# Evaluación en el conjunto el conjunto as
# recall {'female': 0.40161725067385445, 'male': 0.5883838383838383, 'average': 0.4950005445288464}
# precision {'female': 0.4775641025641026, 'male': 0.512087912087912, 'average': 0.49482600732600734}
# f1 {'female': 0.4363103953147877, 'male': 0.5475910693301997, 'average': 0.49195073232249376}
# accuracy 0.4980443285528031

# %%
for metric in ['f1','recall','precision']:
    print(f'{metric} medio de los 3 modelos: \n')
    for task in ['about','to','as']:
        print(task.upper())
        print(f'Resultado global {metric}:',mean(global_metrics[task][metric]['average']))
        print(f'{metric} etiqueta male:',mean(global_metrics[task][metric]['male']))
        print(f'{metric} etiqueta female: ',mean(global_metrics[task][metric]['female']))
        print('\n')

print(f'Accuracy medio de los 3 modelos: \n')
for task in ['about','to','as']:
    print('\n',task.upper())
    print('Resultado global accuracy:',mean(global_metrics[task]['acc']))
# Out:
# f1 medio de los 3 modelos:
#
# ABOUT
# Resultado global f1: 0.4390180630872911
# f1 etiqueta male: 0.40658810991302646
# f1 etiqueta female:  0.47144801626155575
#
#
# TO
# Resultado global f1: 0.43743017167086545
# f1 etiqueta male: 0.4215002304130339
# f1 etiqueta female:  0.45336011292869705
#
#
# AS
# Resultado global f1: 0.438940452269264
# f1 etiqueta male: 0.4197175431645674
# f1 etiqueta female:  0.4581633613739606
#
#
# recall medio de los 3 modelos:
#
# ABOUT
# Resultado global recall: 0.5024305555555555
# recall etiqueta male: 0.4756944444444444
# recall etiqueta female:  0.5291666666666667
#
#
# TO
# Resultado global recall: 0.5063317815200108
# recall etiqueta male: 0.49472830494728304
# recall etiqueta female:  0.5179352580927384
#
#
# AS
# Resultado global recall: 0.5039364897855464
# recall etiqueta male: 0.48316498316498313
# recall etiqueta female:  0.5247079964061097
#
#
# precision medio de los 3 modelos:
#
# ABOUT
# Resultado global precision: 0.4943560795334392
# precision etiqueta male: 0.4867659544388594
# precision etiqueta female:  0.501946204628019
#
#
# TO
# Resultado global precision: 0.5023490690075485
# precision etiqueta male: 0.5096815329373469
# precision etiqueta female:  0.4950166050777502
#
#
# AS
# Resultado global precision: 0.515627031004436
# precision etiqueta male: 0.5377089148793328
# precision etiqueta female:  0.4935451471295392
#
#
# Accuracy medio de los 3 modelos:
#
#
#  ABOUT
# Resultado global accuracy: 0.5029761904761905
#
#  TO
# Resultado global accuracy: 0.5058922558922558
#
#  AS
# Resultado global accuracy: 0.5032594524119948
