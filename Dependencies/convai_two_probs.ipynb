# %%
from parlai.tasks.md_gender import convai2
import parlai.tasks.md_gender.utils as md_utils

from copy import deepcopy

import json

# %%
data_path = '/home/kuina/anaconda3/envs/parlai/lib/python3.10/site-packages/data/'

opt = {'datapath': data_path, #Donde están los datos
    'datatype':'train',
    'labels_to_use':'all',
    'add_unknown_classes': False, # help='Add unknown classes as neutral' # Esto es para incluir o no el about (???)
    'convai2_use_probably':True,
    'balance':False, # help='Whether to balance the data between classes during training',
    'task':'md_gender:convai2',
    #,'balance_valid':False, #help='Whether to balance the validation data'
    'unknown_temp':1.0 #help='Rate at which to sample examples from the unknown class',
}

# %%
convai = convai2.Convai2Teacher(opt)

md_utils.get_data_stats(convai.data,key='labels',lst=True)
# Out:
# [ Building data ... ]
# 16:53:19 | loading fbdialog data: /home/kuina/anaconda3/envs/parlai/lib/python3.10/site-packages/data/ConvAI2/train_both_original.txt
# Missing cnt: 52 / 525768
# Totals for self:
# 	unknown: 87069 (0.6624138403250103)
# 	female: 22036 (0.16764808813012583)
# 	male: 22337 (0.1699380715448639)
# Totals for partner:
# 	unknown: 86422 (0.6574915171710717)
# 	female: 22730 (0.17292798344516974)
# 	male: 22290 (0.1695804993837586)
# Total dataset counts:
# PARTNER:female: 22730
# PARTNER:male: 22290
# PARTNER:unknown: 86422
# SELF:female: 22036
# SELF:male: 22337
# SELF:unknown: 87069

# %%
convai.data[0]
# Out:
# {'text': "the times . i'm a carnivore , how about you ?",
#  'episode_done': True,
#  'your_persona': 'my father used to be a butcher.\nmy only friend is a dog.\ni work at a newspaper.\ni am a carnivore.\ni am highly educated.',
#  'partner_persona': 'i can beat anyone in chess.\ni have high speed internet.\ni got hired as a security guard.\ni saw a solar eclipse when i was 8 years old.',
#  'id': 'ConvAI2 Gender',
#  'labels': ['PARTNER:male'],
#  'class_type': 'partner'}

# %%
data = {}
for item in convai.data:
    text = item['text']
    labels = item['labels'][0]
    class_type = item['class_type']

    if text not in data:

        data[text] = {class_type : [labels]}
    elif text in data and class_type not in data[text]:
        data[text][class_type] = [labels] 
    else:
        data[text][class_type].append(labels)

# %%
data
# Out:
# {"the times . i'm a carnivore , how about you ?": {'partner': ['PARTNER:male',
#    'PARTNER:male'],
#   'self': ['SELF:male', 'SELF:male']},
#  'sounds fancy . any cool perks ?': {'self': ['SELF:female'],
#   'partner': ['PARTNER:unknown']},
#  'that is not embarrassing in this economy': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  'no . what is that ? ?': {'self': ['SELF:female'],
#   'partner': ['PARTNER:female']},
#  'person i am sorry . do you do anything active or are you too tired fo that ?': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'i see i enjoy reading american literature what do you enjoy ?': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'cool . cities are great , i prefer the beach .': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'as a man i am sure you are pretty . we all have issues . like my deafness': {'self': ['SELF:male'],
#   'partner': ['PARTNER:unknown']},
#  '__SILENCE__': {'self': ['SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:female',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:male',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:female',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    ...],
#   'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    ...]},
#  "i'm in cali as well": {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown']},
#  'hi there how are you today ?': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female'],
#   'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:male']},
#  'i do , i bought purple blush once to match my purple hair !': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:female']},
#  'i am from japan . i teach japanese as well': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'i am very , very bad , but that is the norm for me': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:male']},
#  'did you ever do geneology of family history ?': {'self': ['SELF:female'],
#   'partner': ['PARTNER:male']},
#  'hi ! i am doing alright . i am just putting my 3 kids to bed .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'awesome , where is your church located ?': {'self': ['SELF:male',
#    'SELF:male'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  'i love coffee too . i would love to meet you .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'what does that entail exactly ?': {'self': ['SELF:male'],
#   'partner': ['PARTNER:male']},
#  'what do you do ? i work at a bank in a corner office .': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  "that's pretty cool , what are your favorite things to do ?": {'self': ['SELF:female',
#    'SELF:female'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  'shopping is always fun ! i love going to the beach .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:female']},
#  'do you still play ? i love to go to games .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'i sell all kinds of books . i love the ones about bacon the most .': {'partner': ['PARTNER:female'],
#   'self': ['SELF:unknown']},
#  "i don't but you do": {'self': ['SELF:unknown', 'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  'i like anime cartoons and sports . mainly baseball': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'hi ! why not ? maybe you should go fishing .': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  "oh i'm a pro league of legends player": {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown', 'SELF:unknown']},
#  'i am good how are you ?': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:female',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown']},
#  "i love dining out but it gets expensive . that's why i have a second job": {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:female', 'PARTNER:female']},
#  "she's six months pregnant": {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:male', 'SELF:male', 'SELF:male', 'SELF:male']},
#  "that's awesome i don't like cats": {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  "i've one dog name snickers .": {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:male']},
#  "nice to meet you too ! i'm vladimir .": {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'i take my daughter to the park every day': {'self': ['SELF:female',
#    'SELF:female'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  "chocolate . what do you do for a living ? i'm a veterinarian assistant .": {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'banana flavored ice cream so ?': {'self': ['SELF:female'],
#   'partner': ['PARTNER:unknown']},
#  "how many friends you have ? i've many , but cannot count well .": {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown', 'PARTNER:unknown']},
#  'i actually work in marketing . i really love it !': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  "i do not have siblings but i've two dogs . they are terriers .": {'partner': ['PARTNER:male',
#    'PARTNER:male'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'oh you do ? the girl i love likes twilight . she does not know of my love .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:male']},
#  'anything i can dance to while i look in a full length mirror . i bet you like country .': {'self': ['SELF:female'],
#   'partner': ['PARTNER:unknown']},
#  'what does that even entail doing ?': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'i am twenty one ; how about you ?': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'hello ! it is gorgeous corvette weather here .': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:male', 'SELF:male', 'SELF:male']},
#  'it is so sad what happen in fl': {'partner': ['PARTNER:male'],
#   'self': ['SELF:unknown']},
#  'i love to read . reading is one of my favorite': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'nope no pets my cat just died sorry you ?': {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown']},
#  "that's nice do you fish ?": {'partner': ['PARTNER:male', 'PARTNER:male'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  "i'm well . do you have any favorite shows ?": {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown', 'PARTNER:unknown']},
#  'what is your favorite movie': {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female']},
#  'why are you in the hospital': {'self': ['SELF:male',
#    'SELF:male',
#    'SELF:male',
#    'SELF:male',
#    'SELF:male'],
#   'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown']},
#  'at a store right now although i also act . how about you ?': {'partner': ['PARTNER:female'],
#   'self': ['SELF:female']},
#  'it does for only that time but when am alone i feel sorrowful .': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  'i love to hear that . what does she do for a living ?': {'self': ['SELF:male',
#    'SELF:male'],
#   'partner': ['PARTNER:female', 'PARTNER:female']},
# ...
#  'i hope you have both . i gotta run and clean my apartment': {'partner': ['PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:female'],
#   'self': ['SELF:unknown', 'SELF:unknown', 'SELF:unknown', 'SELF:unknown']},
#  'mine is steelers . . . so did you ever go to college ?': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'i attend nyu as a student .': {'partner': ['PARTNER:male', 'PARTNER:male'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'do you ever go snowboarding ?': {'partner': ['PARTNER:female',
#    'PARTNER:female'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'i love kids i have several nieces and nephews': {'partner': ['PARTNER:male'],
#   'self': ['SELF:unknown']},
#  'i run a lot , my wife cut out of me . it is cool .': {'self': ['SELF:male',
#    'SELF:male'],
#   'partner': ['PARTNER:female', 'PARTNER:female']},
#  'yes . as long as you do not throw snowballs at them .': {'partner': ['PARTNER:female',
#    'PARTNER:female'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'check out face off on syfy . it will make you feel different .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:female']},
#  'i hope i settle down . my parents are both doctors and want me to marry one too': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:male']},
#  "hi , i'm doing ok ? what are you working on ?": {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'you are fortunate . i spend quiet time watching cartoons .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'that is a shame . but you have a positive attitude !': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  'lol i guess some of them are . i love partying at the beach': {'partner': ['PARTNER:female',
#    'PARTNER:female'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'i love art too which is why i like museums so much .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:male']},
#  'florida , kinda far but your can knit something for me': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:female', 'PARTNER:female']},
#  'what are you in school for ?': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown', 'SELF:unknown']},
#  'oh where do you work ?': {'partner': ['PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male']},
#  'hello . i do not have any but have kids and a wife . you ?': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:male', 'SELF:male', 'SELF:male']},
#  'yes i am . though i could definitely get a job as a pro eater': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'whew ! chicken wings are our friends . you arm wrestle ? i do .': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  'that would be awesome , i teach 26 kids ! what do you enjoy in your free time ?': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:male']},
#  'rough childhood i take it ? so what do you do ?': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown', 'SELF:unknown']},
#  'oh , you like the colder weather ?': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:male', 'PARTNER:male']},
#  "i'm good , did you ride skateboard to school ?": {'self': ['SELF:female',
#    'SELF:female'],
#   'partner': ['PARTNER:female', 'PARTNER:female']},
#  'or distraction . . . . . its crazy how its caught on': {'partner': ['PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male'],
#   'self': ['SELF:unknown', 'SELF:unknown', 'SELF:unknown', 'SELF:unknown']},
#  "yeah mine chip quite a bit so i've to get them done every week": {'self': ['SELF:female'],
#   'partner': ['PARTNER:female']},
#  'just hanging at home with my pet lizard . what are you up to ?': {'partner': ['PARTNER:female',
#    'PARTNER:female'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'that is great what is your favorite meal': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'that is good . seen any good movies recently ?': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown', 'SELF:unknown']},
#  'i know what you mean . last month i decided i was done with college .': {'partner': ['PARTNER:female',
#    'PARTNER:female'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  "i wish i could . but knowing me , i'd write , re write , it would never be good enough !": {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'dang that does sound nice though': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'hi there ! just a little tired from working so late . yourself ?': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  "i'm watching smart guy on dvd . how is the weather there ?": {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'do you live on the ocean': {'self': ['SELF:female',
#    'SELF:female',
#    'SELF:female',
#    'SELF:female'],
#   'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown']},
#  'wow where did you see them can i see them soon': {'self': ['SELF:female',
#    'SELF:female'],
#   'partner': ['PARTNER:male', 'PARTNER:male']},
#  'i know . i just got to find the time .': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:female', 'SELF:female']},
#  "do you play any sports ? i've been playing softball since highschool !": {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:male', 'PARTNER:male', 'PARTNER:male']},
#  'i run research at a french fry company': {'partner': ['PARTNER:female'],
#   'self': ['SELF:unknown']},
#  'hey there how are you': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male'],
#   'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female']},
#  "oh okay . i'm a single parent mom i've 5 kids .": {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:female', 'SELF:female']},
#  "that i'm , wow that is really cool . also how did you know ?": {'self': ['SELF:male',
#    'SELF:male',
#    'SELF:male'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown', 'PARTNER:unknown']},
#  'cool i started on a new team last month .': {'partner': ['PARTNER:female',
#    'PARTNER:female'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'homemade liver and onions': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  "i've not gotten back to my home if over 2 years .": {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:female', 'PARTNER:female']},
#  'yeah save the world and stuff': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:male']},
#  'i make ask and barely work at all .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  "congratulations , i'd bake you a cake if i could .": {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:male']},
#  'you can spray the flowers with nightlock and the cats will not bother it anymore': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'its my favorite . grey can be calming though .': {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown', 'PARTNER:unknown']},
#  'interesting . are you single ? married ?': {'partner': ['PARTNER:female'],
#   'self': ['SELF:unknown']},
#  'oh wow that sounds like fun have you thought of joining a team': {'self': ['SELF:male',
#    'SELF:male',
#    'SELF:male'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown', 'PARTNER:unknown']},
#  'i have no brothers and sisters here at home so i walk alone': {'self': ['SELF:female',
#    'SELF:female'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  'live there in summer and here in winter and eat large portions of lean meat': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:male', 'PARTNER:male']},
#  "that's awesome i'd love to learn how to do that !": {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:female']},
#  'oh that sounds delicious ! i bet my crush would love that': {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:female', 'PARTNER:female', 'PARTNER:female']},
#  "i don't like it much either .": {'partner': ['PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male'],
#   'self': ['SELF:unknown', 'SELF:unknown', 'SELF:unknown']},
#  'do you enjoy cooking or going out to eat more ?': {'self': ['SELF:male',
#    'SELF:male'],
#   'partner': ['PARTNER:female', 'PARTNER:female']},
#  'i am basically a gym rat . but i try to read often too .': {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown', 'PARTNER:unknown']},
#  "yes i'm a christian . i work as a vet tech . what about you ?": {'partner': ['PARTNER:male'],
#   'self': ['SELF:unknown']},
#  'yes , i just told you , , matter a fact i got playing the background': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:female']},
#  "sounds good . do you have a job ? hopefully you aren't a clown . i hate them": {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:female']},
#  'i like to make money for fun': {'self': ['SELF:unknown', 'SELF:unknown'],
#   'partner': ['PARTNER:male', 'PARTNER:male']},
#  'i work in pharmaceuticals . you ?': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown', 'SELF:unknown', 'SELF:unknown']},
#  "that's where i work . and she has lots of kids . she will have ideas .": {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:female']},
#  "cool ! do you like leather ? i've leather everything !": {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:female']},
#  'they are teens so they prefer women in bikinis on their walls lol': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:female', 'SELF:female']},
#  'i write travel guids for lonely planet .': {'self': ['SELF:male',
#    'SELF:male',
#    'SELF:male'],
#   'partner': ['PARTNER:male', 'PARTNER:male', 'PARTNER:male']},
#  'i only like to read tech manuals . i m into radio controlled racing . you ?': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'that is a great idea do you have a job': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:male']},
#  'the joys of being single , i suppose': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown', 'SELF:unknown', 'SELF:unknown']},
#  'hey i play drums too . i play rock , country and all kinds': {'partner': ['PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male'],
#   'self': ['SELF:unknown', 'SELF:unknown', 'SELF:unknown', 'SELF:unknown']},
#  'hi there !': {'partner': ['PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male'],
#   'self': ['SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown']},
#  'yes , i try to be i often do makeup videos': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  "that's nice , i just broke my leg today": {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'i make comics book , amd drawing': {'self': ['SELF:unknown', 'SELF:unknown'],
#   'partner': ['PARTNER:male', 'PARTNER:male']},
#  'yes going out to shop for things i need through the week': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'sure , we can try it out': {'partner': ['PARTNER:female'],
#   'self': ['SELF:unknown']},
#  'not at all there are about eight of us .': {'self': ['SELF:male'],
#   'partner': ['PARTNER:female']},
#  'i do . its a great job and helps me provide for my daughters .': {'self': ['SELF:female'],
#   'partner': ['PARTNER:unknown']},
#  'hello how are you doing ?': {'partner': ['PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown']},
#  'its true , but i would not want to stay away from family .': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  "oh wow that's awesome . i'm in college but get teased cause i'm transgender": {'partner': ['PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male'],
#   'self': ['SELF:female', 'SELF:female', 'SELF:female', 'SELF:female']},
#  'hello , how are you ? i just got off from working for a magazine . you ?': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  'i wrote a book about cats who eat tacos while watching movies on sundays .': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:female', 'SELF:female']},
#  "at 53 and my bones could not handle sports , i don't believe .": {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:female', 'PARTNER:female']},
#  'oh , neat ! yoga instructor here . my wife is a diesel mechanic .': {'partner': ['PARTNER:male',
#    'PARTNER:male'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  "i'm sorry for your loss this dog was my mothers she too passed": {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:female', 'PARTNER:female']},
#  "that's exciting ! i am just a little girl . i am still in preschool .": {'self': ['SELF:female',
#    'SELF:female'],
#   'partner': ['PARTNER:female', 'PARTNER:female']},
#  'that sounds nice to have her around': {'self': ['SELF:male', 'SELF:male'],
#   'partner': ['PARTNER:female', 'PARTNER:female']},
#  "my sister lives in ny so she's far away . do you live near your parents ?": {'self': ['SELF:male'],
#   'partner': ['PARTNER:unknown']},
#  'yellow apples . how about yours ?': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:female']},
#  ...}

# %%
#Opción A: Dejo unknown con su probabilidad
A_data = deepcopy(data)
for item in A_data:
    partner = A_data[item]['partner']
    your = A_data[item]['self']
    partner_labels = {label : partner.count(label)/len(partner) for label in set(partner)}
    your_labels = {label : your.count(label)/len(your) for label in set(your)}

    A_data[item]['partner'] = partner_labels
    A_data[item]['self'] = your_labels

# %%
#Opción B: Reemplazo unknown por male y female y calculo probabilidades

from itertools import chain


B_data = deepcopy(data)
for item in B_data:
    partner = list(chain.from_iterable(['PARTNER:male','PARTNER:female'] if x == 'PARTNER:unknown' else [x] for x in B_data[item]['partner']) )
    your = list(chain.from_iterable(['SELF:male','SELF:female'] if x == 'SELF:unknown' else [x] for x in B_data[item]['self']) )

    partner_labels = {label : partner.count(label)/len(partner) for label in set(partner)}
    your_labels = {label : your.count(label)/len(your) for label in set(your)}

    B_data[item]['partner'] = partner_labels
    B_data[item]['self'] = your_labels

# %%
with open('convai_two_unk.json','w') as f:
    json.dump(A_data,f)

with open('convai_two_NO_unk.json','w') as f:
    json.dump(B_data,f)
