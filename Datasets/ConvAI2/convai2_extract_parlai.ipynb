# %%
from parlai.tasks.md_gender import convai2
import parlai.tasks.md_gender.utils as md_utils

from copy import deepcopy

import json

# %%
data_path = '/home/kuina/anaconda3/envs/parlai/lib/python3.10/site-packages/data/'

opt = {'datapath': data_path, #Donde están los datos
    'datatype':'train',
    'labels_to_use':'all',
    'add_unknown_classes': False, # help='Add unknown classes as neutral' # Esto es para incluir o no el about (???)
    'convai2_use_probably':True,
    'balance':False, # help='Whether to balance the data between classes during training',
    'task':'md_gender:convai2',
    #,'balance_valid':False, #help='Whether to balance the validation data'
    'unknown_temp':1.0 #help='Rate at which to sample examples from the unknown class',
}

# %%
convai = convai2.Convai2Teacher(opt)

md_utils.get_data_stats(convai.data,key='labels',lst=True)
# Out:
# [ Building data ... ]
# 15:57:52 | loading fbdialog data: /home/kuina/anaconda3/envs/parlai/lib/python3.10/site-packages/data/ConvAI2/train_both_original.txt
# Missing cnt: 66 / 525772
# Totals for self:
# 	unknown: 86890 (0.6610469937539466)
# 	female: 22439 (0.17071278044475552)
# 	male: 22114 (0.1682402258012979)
# Totals for partner:
# 	unknown: 87456 (0.6653530427637835)
# 	female: 22138 (0.1684228144518917)
# 	male: 21849 (0.16622414278432476)
# Total dataset counts:
# PARTNER:female: 22138
# PARTNER:male: 21849
# PARTNER:unknown: 87456
# SELF:female: 22439
# SELF:male: 22114
# SELF:unknown: 86890

# %%
convai.data[0]
# Out:
# {'text': "good choice . i haven't figured out what i want to do yet .",
#  'episode_done': True,
#  'your_persona': "i still live at home.\ni listen to death metal.\ni like cartoons.\ni'm in college.",
#  'partner_persona': 'both my parents are creative.\nmy dad works in the automotive industry.\ni m a student living at home while pursuing my music industry degree.\ni dream of playing music for a living.',
#  'id': 'ConvAI2 Gender',
#  'labels': ['PARTNER:unknown'],
#  'class_type': 'partner'}

# %%
data = {}
for item in convai.data:
    text = item['text']
    labels = item['labels'][0]
    class_type = item['class_type']

    if text not in data:

        data[text] = {class_type : [labels]}
    elif text in data and class_type not in data[text]:
        data[text][class_type] = [labels] 
    else:
        data[text][class_type].append(labels)

# %%
data
# Out:
# {"good choice . i haven't figured out what i want to do yet .": {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  "that's ok , i also love to watch horror shows ; do you ?": {'partner': ['PARTNER:male'],
#   'self': ['SELF:unknown']},
#  'i like science as well': {'self': ['SELF:unknown', 'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  'i just crunched up halloween oreos into some ice cream . pretty good .': {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown', 'PARTNER:unknown']},
#  "sometimes i do . while i'm asleep": {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:male', 'SELF:male']},
#  'haha ! just do not let her hear you say that !': {'self': ['SELF:male'],
#   'partner': ['PARTNER:male']},
#  'ouch , stay safe ! hows the traffic there ?': {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown', 'PARTNER:unknown']},
#  'well , i do work at a party store ! love to party !': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  "ya they don't like that i believe in any a .": {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown', 'PARTNER:unknown']},
#  'haha ! yeah i love meat , vegetable too': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'what do you play in the band ? or are you the lead singer ?': {'self': ['SELF:male',
#    'SELF:male',
#    'SELF:male'],
#   'partner': ['PARTNER:male', 'PARTNER:male', 'PARTNER:male']},
#  '__SILENCE__': {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:male',
#    'SELF:male',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:male',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:male',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    ...],
#   'partner': ['PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    ...]},
#  'that is nice . do you live in a city ?': {'self': ['SELF:female'],
#   'partner': ['PARTNER:unknown']},
#  "i actually know the chain smokers . they're pretty good .": {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown', 'PARTNER:unknown']},
#  "is there ? i'm not sure of that": {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:male']},
#  'right , i forgot . sorry , so busy with these house projects !': {'partner': ['PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:female'],
#   'self': ['SELF:unknown', 'SELF:unknown', 'SELF:unknown']},
#  "wow that's crazy i would love to hear": {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'you may need to contact someone immediately until you can get therapy . hotlines are there .': {'partner': ['PARTNER:male',
#    'PARTNER:male'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'hello , frank . i am art . tell me something interesting about yourself .': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:male', 'PARTNER:male']},
#  'yes i like classic rock . what about you ?': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  'yes i am in atlanta and people are freaking out .': {'self': ['SELF:male'],
#   'partner': ['PARTNER:unknown']},
#  'so sorry man . being former military i lost a lot of people . it sucks .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:male']},
#  'i miss simpler times just watching grandma bake all day': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  "cool ! whenever i've the time i like to go skateboarding .": {'self': ['SELF:female'],
#   'partner': ['PARTNER:unknown']},
#  'i work from home as a editor .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'i play volley ball in my free time and happy alone .': {'partner': ['PARTNER:male',
#    'PARTNER:male'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'i do ballet and barre . occasionally , i run .': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'yes , it little bit expensive but too healthy': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:female', 'SELF:female', 'SELF:female', 'SELF:female']},
#  'i feel the same . i feel i could sleep for days . what do you enjoy ?': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown']},
#  "i'm still in school so its just a hobby for now .": {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:female', 'PARTNER:female']},
#  'alas not so much , but my close friends and family do enjoy my blends': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown', 'SELF:unknown', 'SELF:unknown']},
#  'i get it . fish is my second favorite after syrup and pancakes': {'self': ['SELF:male'],
#   'partner': ['PARTNER:unknown']},
#  "that's a lot of weight . i spend my spare time writing novels .": {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown', 'PARTNER:unknown']},
#  'i can definitely understand that . i love vegetables so i decided to grow them .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'i enjoy reading and crocheting for charity .': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'i enjoy the voice as well . do you sing ?': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:male', 'SELF:male']},
#  'any type of series . hate to read just one and its over': {'partner': ['PARTNER:female',
#    'PARTNER:female'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'too bad the u . s . team did not make it to the world cup': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  'no . i have a little brother . same thing . you cook ?': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:male']},
#  'are you spoiled ? ll i bet': {'self': ['SELF:female',
#    'SELF:female',
#    'SELF:female'],
#   'partner': ['PARTNER:male', 'PARTNER:male', 'PARTNER:male']},
#  'hello , where are you from ? i live in the great state of georgia': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'hey there , how is your day ?': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:female', 'SELF:female', 'SELF:female']},
#  'yes they do . so what is your favorite color ? mine is green .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'i love to exercise and ride horses': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'how often do you play': {'self': ['SELF:female'],
#   'partner': ['PARTNER:male']},
#  'that is cool i like black': {'self': ['SELF:unknown', 'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  'very cool , i am currently taking classes online . it is easier with my daughter .': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown', 'SELF:unknown']},
#  'me night is going good !': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'i can tell you are crazy do you know why ?': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  "i'm sure you have a lot of interesting experience . its just me and my son": {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:male', 'SELF:male']},
#  'do you wonder what it would be like to be a different gender ?': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'hello how are you this evening ?': {'self': ['SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:female',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male']},
#  'i love reading': {'partner': ['PARTNER:male'], 'self': ['SELF:unknown']},
# ...
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:female', 'PARTNER:female', 'PARTNER:female']},
#  'what kind of job do you have ?': {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:female', 'PARTNER:unknown', 'PARTNER:female']},
#  'hi , not really . i enjoy summer .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'what are you majoring in ?': {'partner': ['PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown', 'SELF:unknown', 'SELF:unknown']},
#  "200 feet , i'm sorry . my vision is terrible and i get bad headaches": {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:male', 'PARTNER:male', 'PARTNER:male']},
#  'thanks a lot ! lets see . it is my first .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  "i don't drink either . i just don't like irt !": {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:female', 'SELF:female', 'SELF:female']},
#  'good and how are you ?': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'it is 930 got to get up early to take my bf to acting school .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:female']},
#  'candy is great . one of my favorites .': {'self': ['SELF:male'],
#   'partner': ['PARTNER:unknown']},
#  'which club were you with ?': {'self': ['SELF:male'],
#   'partner': ['PARTNER:female']},
#  'what ! ? the real will ferrell ! how did you meet him ?': {'partner': ['PARTNER:male',
#    'PARTNER:male'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'definitely a topic i know nothing about ! do you come from a celtic heritage ?': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:male', 'SELF:male', 'SELF:male', 'SELF:male', 'SELF:male']},
#  "i'm not very good at spanish , but i did take it in high school .": {'self': ['SELF:male'],
#   'partner': ['PARTNER:unknown']},
#  'yes , just the dead ends . what else do you enjoy ?': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  "oh that's neat . my grandmother passed away a few years ago .": {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown', 'PARTNER:unknown']},
#  'well thank you . do you have kids ?': {'partner': ['PARTNER:female'],
#   'self': ['SELF:unknown']},
#  "i've a son so maybe and he loves blue lol .": {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:male', 'SELF:male']},
#  'i did not get to go to college': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:male', 'SELF:male', 'SELF:male']},
#  'manchester united ! yours ?': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'blue is best , though . i always go for blue whenever i can .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'we have one at work , even though i do not use it .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:male']},
#  "i hope so as she's like our baby . hoping we can adopt a real one though": {'self': ['SELF:female'],
#   'partner': ['PARTNER:unknown']},
#  'lol i dunno . my youngest sis is in 1st grade . we could test it on her haha': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown', 'SELF:unknown', 'SELF:unknown']},
#  'i just sell . i used to play guitar but it has been awhile .': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown']},
#  'what part of the country do you live ?': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:female', 'PARTNER:female']},
#  "hey , i'm craig . thanks for chatting with me , how are you ?": {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'i am not sure yet . maybe some type of engineering': {'self': ['SELF:female',
#    'SELF:female'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  'ours will be worse . the pharmacy will be closed tomorrow , three day weekend . yay !': {'partner': ['PARTNER:male',
#    'PARTNER:male'],
#   'self': ['SELF:female', 'SELF:female']},
#  'i write poetry too . helps with the trama i got as a marine': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:female']},
#  'just boring studying and looking over client files all weekend . how are you ?': {'self': ['SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  'really ? maybe i need to see her . mine does not understand me .': {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown', 'PARTNER:unknown']},
#  'i am not into music . what do you do for exercise or sport ?': {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:male', 'PARTNER:male', 'PARTNER:male']},
#  'hi how are you today ?': {'partner': ['PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:male',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:male',
#    'SELF:female',
#    'SELF:unknown']},
#  'i am at university of michigan .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:male']},
#  'i like shopping there from time to time . i am retired': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:male', 'SELF:male', 'SELF:male']},
#  'one of my room mates picks on me . the other room mate agrees .': {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown']},
#  'my mom the best baker the family': {'self': ['SELF:unknown', 'SELF:unknown'],
#   'partner': ['PARTNER:unknown', 'PARTNER:unknown']},
#  'pancakes are one of my very favorites i am not vegan .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'i am in my twenties . you ?': {'self': ['SELF:unknown', 'SELF:unknown'],
#   'partner': ['PARTNER:female', 'PARTNER:female']},
#  'my 2 brothers are same as mine .': {'partner': ['PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown',
#    'PARTNER:unknown'],
#   'self': ['SELF:unknown', 'SELF:unknown', 'SELF:unknown', 'SELF:unknown']},
#  "so watch out cows . i've a terrible confession to male .": {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:male', 'PARTNER:male', 'PARTNER:male']},
#  'oh , do you do any performing ? i love getting out there and meeting people .': {'partner': ['PARTNER:male'],
#   'self': ['SELF:unknown']},
#  'hi names ned and i love to eat fast food a lot ,': {'self': ['SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown',
#    'SELF:unknown'],
#   'partner': ['PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:female',
#    'PARTNER:female']},
#  'well i do not have a job because i broke my nose when i was 10': {'partner': ['PARTNER:female',
#    'PARTNER:female'],
#   'self': ['SELF:unknown', 'SELF:unknown']},
#  'we do . you should stop by and see all the choices we have .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:male']},
#  'really mellow . just drank the best beer from china ! who knew ?': {'self': ['SELF:male',
#    'SELF:male'],
#   'partner': ['PARTNER:female', 'PARTNER:female']},
#  ...}

# %%
#Opción A: Dejo unknown con su probabilidad
A_data = deepcopy(data)
for item in A_data:
    partner = A_data[item]['partner']
    your = A_data[item]['self']
    partner_labels = {label : partner.count(label)/len(partner) for label in set(partner)}
    your_labels = {label : your.count(label)/len(your) for label in set(your)}

    A_data[item]['partner'] = partner_labels
    A_data[item]['self'] = your_labels

# %%
#Opción B: Reemplazo unknown por male y female y calculo probabilidades

from itertools import chain


B_data = deepcopy(data)
for item in B_data:
    partner = list(chain.from_iterable(['PARTNER:male','PARTNER:female'] if x == 'PARTNER:unknown' else [x] for x in B_data[item]['partner']) )
    your = list(chain.from_iterable(['SELF:male','SELF:female'] if x == 'SELF:unknown' else [x] for x in B_data[item]['self']) )

    partner_labels = {label : partner.count(label)/len(partner) for label in set(partner)}
    your_labels = {label : your.count(label)/len(your) for label in set(your)}

    B_data[item]['partner'] = partner_labels
    B_data[item]['self'] = your_labels

# %%
# Opción C: No almaceno probabilidades

C_data = deepcopy(data)
for item in C_data:
    C_data[item]['partner'] = list(dict.fromkeys(C_data[item]['partner']))
    C_data[item]['self'] = list(dict.fromkeys(C_data[item]['self']))

# %%
C_data
# Out:
# {"good choice . i haven't figured out what i want to do yet .": {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  
{'self': ['SELF:female'],
#   'partner': ['PARTNER:unknown']},
#  'lol what ? okay then i guess': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  "i really like youtube , my dad and i've our own channel": {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'are you busy tomorrow ?': {'partner': ['PARTNER:male'],
#   'self': ['SELF:female']},
#  'oh i am about five seven now a days': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'i wish i could multiply myself lol': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'maybe i can add some other steampunk elements to it ; but i have not worked out the engineering . . .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:male']},
#  'neat my dad is very strict we can event get a cat !': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'what kind of diet is that ?': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:male']},
#  "that's cool , i don't have time for anything but football !": {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:male']},
#  'what roles do you like playing ?': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'i love that . i bet my 3 dogs would too': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:female']},
#  'what kind of job do you have ?': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:female', 'PARTNER:unknown']},
#  'hi , not really . i enjoy summer .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'what are you majoring in ?': {'partner': ['PARTNER:unknown', 'PARTNER:male'],
#   'self': ['SELF:unknown']},
#  "200 feet , i'm sorry . my vision is terrible and i get bad headaches": {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:male']},
#  'thanks a lot ! lets see . it is my first .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  "i don't drink either . i just don't like irt !": {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:female']},
#  'good and how are you ?': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'it is 930 got to get up early to take my bf to acting school .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:female']},
#  'candy is great . one of my favorites .': {'self': ['SELF:male'],
#   'partner': ['PARTNER:unknown']},
#  'which club were you with ?': {'self': ['SELF:male'],
#   'partner': ['PARTNER:female']},
#  'what ! ? the real will ferrell ! how did you meet him ?': {'partner': ['PARTNER:male'],
#   'self': ['SELF:unknown']},
#  'definitely a topic i know nothing about ! do you come from a celtic heritage ?': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:male']},
#  "i'm not very good at spanish , but i did take it in high school .": {'self': ['SELF:male'],
#   'partner': ['PARTNER:unknown']},
#  'yes , just the dead ends . what else do you enjoy ?': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  "oh that's neat . my grandmother passed away a few years ago .": {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'well thank you . do you have kids ?': {'partner': ['PARTNER:female'],
#   'self': ['SELF:unknown']},
#  "i've a son so maybe and he loves blue lol .": {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:male']},
#  'i did not get to go to college': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:male']},
#  'manchester united ! yours ?': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'blue is best , though . i always go for blue whenever i can .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'we have one at work , even though i do not use it .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:male']},
#  "i hope so as she's like our baby . hoping we can adopt a real one though": {'self': ['SELF:female'],
#   'partner': ['PARTNER:unknown']},
#  'lol i dunno . my youngest sis is in 1st grade . we could test it on her haha': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'i just sell . i used to play guitar but it has been awhile .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'what part of the country do you live ?': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:female']},
#  "hey , i'm craig . thanks for chatting with me , how are you ?": {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'i am not sure yet . maybe some type of engineering': {'self': ['SELF:female'],
#   'partner': ['PARTNER:unknown']},
#  'ours will be worse . the pharmacy will be closed tomorrow , three day weekend . yay !': {'partner': ['PARTNER:male'],
#   'self': ['SELF:female']},
#  'i write poetry too . helps with the trama i got as a marine': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:female']},
#  'just boring studying and looking over client files all weekend . how are you ?': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'really ? maybe i need to see her . mine does not understand me .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'i am not into music . what do you do for exercise or sport ?': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:male']},
#  'hi how are you today ?': {'partner': ['PARTNER:female',
#    'PARTNER:unknown',
#    'PARTNER:male'],
#   'self': ['SELF:unknown', 'SELF:male', 'SELF:female']},
#  'i am at university of michigan .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:male']},
#  'i like shopping there from time to time . i am retired': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:male']},
#  'one of my room mates picks on me . the other room mate agrees .': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'my mom the best baker the family': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:unknown']},
#  'pancakes are one of my very favorites i am not vegan .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  'i am in my twenties . you ?': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:female']},
#  'my 2 brothers are same as mine .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:unknown']},
#  "so watch out cows . i've a terrible confession to male .": {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:male']},
#  'oh , do you do any performing ? i love getting out there and meeting people .': {'partner': ['PARTNER:male'],
#   'self': ['SELF:unknown']},
#  'hi names ned and i love to eat fast food a lot ,': {'self': ['SELF:unknown'],
#   'partner': ['PARTNER:female']},
#  'well i do not have a job because i broke my nose when i was 10': {'partner': ['PARTNER:female'],
#   'self': ['SELF:unknown']},
#  'we do . you should stop by and see all the choices we have .': {'partner': ['PARTNER:unknown'],
#   'self': ['SELF:male']},
#  'really mellow . just drank the best beer from china ! who knew ?': {'self': ['SELF:male'],
#   'partner': ['PARTNER:female']},
#  ...}

# %%
with open('convai_dataset_with_unk.json','w') as f:
    json.dump(C_data,f)

# %%
with open('convai_two_unk.json','w') as f:
    json.dump(A_data,f)

with open('convai_two_NO_unk.json','w') as f:
    json.dump(B_data,f)
